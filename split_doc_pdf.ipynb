# %% [markdown]
# ### Check if PDF is ok

# %%
import os
from PyPDF2 import PdfReader
import logging

def is_pdf_valid(file_path):
    """
    Checks if a PDF file is valid and not corrupted.

    Parameters:
        file_path (str): The path to the PDF file.

    Returns:
        bool: True if the PDF is valid, False otherwise.
    """
    try:
        with open(file_path, 'rb') as f:
            reader = PdfReader(f)
            # Attempt to read the number of pages
            num_pages = len(reader.pages)
        return True
    except Exception as e:
        logging.error(f"Error reading {file_path}: {e}")
        return False

def check_pdfs_in_folder(folder_path):
    """
    Checks all PDF files in a folder for validity.

    Parameters:
        folder_path (str): The path to the folder containing PDF files.

    Returns:
        tuple: Lists of valid and invalid PDF file paths.
    """
    valid_pdfs = []
    invalid_pdfs = []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith('.pdf'):
            file_path = os.path.join(folder_path, filename)
            if is_pdf_valid(file_path):
                # print(f"{filename} is valid.")
                valid_pdfs.append(file_path)
                # Proceed to process the PDF
            else:
                print(f"{filename} is corrupted or invalid.")
                invalid_pdfs.append(file_path)
    return valid_pdfs, invalid_pdfs

if __name__ == "__main__":
    # Configure logging to write errors to a file
    logging.basicConfig(filename='pdf_errors.log', level=logging.ERROR)

    # Replace 'path_to_your_folder' with the path to your folder containing PDFs
    folder_path = r"D:\all\cp_CT_Procur\CT_Procur_merge_doc_3735 - Copy"
    valid_pdfs, invalid_pdfs = check_pdfs_in_folder(folder_path)

    print(f"\nValid PDFs ({len(valid_pdfs)}):")
    # for pdf in valid_pdfs:
    #     print(pdf)

    print(f"\nInvalid PDFs ({len(invalid_pdfs)}):")
    for pdf in invalid_pdfs:
        print(pdf)
# Out:
# Cam kết năm sản xuất XP2i - Vector Infotech.pdf is corrupted or invalid.
# PO2407053-01-full signed.pdf is corrupted or invalid.
# sailor-sart-ii-type-examination-certificate-module-b_tuv.pdf is corrupted or invalid.
# sign-F58_Vendor Registration Form_Rev1.pdf is corrupted or invalid.
#
# Valid PDFs (3727):
#
# Invalid PDFs (4):
# D:\all\cp_CT_Procur\CT_Procur_merge_doc_3735 - Copy\Cam kết năm sản xuất XP2i - Vector Infotech.pdf
# D:\all\cp_CT_Procur\CT_Procur_merge_doc_3735 - Copy\PO2407053-01-full signed.pdf
# D:\all\cp_CT_Procur\CT_Procur_merge_doc_3735 - Copy\sailor-sart-ii-type-examination-certificate-module-b_tuv.pdf
# D:\all\cp_CT_Procur\CT_Procur_merge_doc_3735 - Copy\sign-F58_Vendor Registration Form_Rev1.pdf

# %% [markdown]
# ### Compare filename without extension between DOC and PDF folders

# %%
import os
from pathlib import Path

def get_filename_without_extension(filename: str) -> str:
    """
    Extract filename without extension.
    Example: 'document.pdf' -> 'document'
    
    Args:
        filename (str): Full filename with extension
        
    Returns:
        str: Filename without extension
    """
    return Path(filename).stem

def compare_folders(folder_a_path: str, folder_b_path: str) -> tuple[list[tuple[str, str]], int]:
    """
    Compare two folders and find files that exist in folder A but not in folder B,
    ignoring file extensions.
    
    Args:
        folder_a_path (str): Path to folder A
        folder_b_path (str): Path to folder B
        
    Returns:
        tuple: List of tuples (filename with extension, filename without extension) 
        unique to folder A and count of such files
    """
    # Convert paths to Path objects
    folder_a = Path(folder_a_path)
    folder_b = Path(folder_b_path)
    
    # Get filenames with and without extensions
    files_a = [(file.name, get_filename_without_extension(file.name)) 
               for file in folder_a.iterdir() if file.is_file()]
    files_b = [get_filename_without_extension(file.name) 
               for file in folder_b.iterdir() if file.is_file()]
    
    # Find files that are in A but not in B (comparing without extensions)
    unique_to_a = [(full_name, name_without_ext) 
                   for full_name, name_without_ext in files_a 
                   if name_without_ext not in files_b]
    
    # Sort the list by filename without extension for better readability
    unique_to_a.sort(key=lambda x: x[1])
    
    return unique_to_a, len(unique_to_a)

def main():
    # Replace these paths with your actual folder paths
    folder_a_path = r"F:\orig\CT_doc_files"
    folder_b_path = r"F:\orig\CT_in_Procur_merge_11184_orig - Copy"
    
    try:
        unique_files, count = compare_folders(folder_a_path, folder_b_path)
        
        print(f"\nFound {count} files in folder A that are not in folder B (ignoring extensions):\n")
        
        # Group files by base name for better organization
        current_base = None
        for full_name, base_name in unique_files:
            if base_name != current_base:
                print(f"\nBase name: {base_name}")
                current_base = base_name
            print(f"  - {full_name}")
            
    except FileNotFoundError as e:
        print(f"Error: {e}")
        print("Please check if both folder paths exist and are accessible.")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Found 1868 files in folder A that are not in folder B (ignoring extensions):
#
#
# Base name: ! Vilas 60 HƯỚNG DẪN CHI TIẾT ĐO KIỂM
#   - ! Vilas 60 HƯỚNG DẪN CHI TIẾT ĐO KIỂM.docx
#
# Base name: !!! Hop chuan, hop quy, do kiem
#   - !!! Hop chuan, hop quy, do kiem.docx
#
# Base name: !!! Note
#   - !!! Note.docx
#
# Base name: #10_HD VMPC-VECTOR 20231003 (FINAL)
#   - #10_HD VMPC-VECTOR 20231003 (FINAL).doc
#
# Base name: (RV1)HỢP ĐỒNG AMIVN- VECTOR cmt
#   - (RV1)HỢP ĐỒNG AMIVN- VECTOR cmt.docx
#
# Base name: 0. Bang ke chung tu thuoc Phu luc III
#   - 0. Bang ke chung tu thuoc Phu luc III.doc
#
# Base name: 0. Phụ lục HD 03_V2_Vector cmt
#   - 0. Phụ lục HD 03_V2_Vector cmt.doc
#
# Base name: 01.PLDC
#   - 01.PLDC.docx
#
# Base name: 0110-HĐMB-KTV-VIVN-2024 - cmt
#   - 0110-HĐMB-KTV-VIVN-2024 - cmt.doc
#
# Base name: 01_Purchase Contract_Terms  Conditions_G2
#   - 01_Purchase Contract_Terms  Conditions_G2.docx
#
# Base name: 02_Exhibit I_Schedule of Rates  Prices_G2
#   - 02_Exhibit I_Schedule of Rates  Prices_G2.docx
#
# Base name: 03. Bao cao tong hoat do, luong hoat do ban giao
#   - 03. Bao cao tong hoat do, luong hoat do ban giao.doc
#
# Base name: 037622-HBMB-KD-Contract Vector_Long Son Petrochemicals ND
#   - 037622-HBMB-KD-Contract Vector_Long Son Petrochemicals ND.doc
#
# Base name: 042-Contract-Omnitech-102014 (rev1)
#   - 042-Contract-Omnitech-102014 (rev1).docx
#
# Base name: 042-Contract-Omnitech-102014 (rev2) on Oct 29 by Ngoc - Copy
#   - 042-Contract-Omnitech-102014 (rev2) on Oct 29 by Ngoc - Copy.docx
#
# Base name: 042-Contract-Omnitech-102014 (rev3) on Nov 14 by Ngoc FINAL
#   - 042-Contract-Omnitech-102014 (rev3) on Nov 14 by Ngoc FINAL.docx
#
# Base name: 05.2014.TT.BTTTT
#   - 05.2014.TT.BTTTT.doc
#
# Base name: 05.2014.TT.BTTTT.Phu luc
#   - 05.2014.TT.BTTTT.Phu luc.doc
#
# Base name: 1  Don nhap khau  - done
#   - 1  Don nhap khau  - done.doc
#
# Base name: 1 TĐG RLX2-IHNF-A
#   - 1 TĐG RLX2-IHNF-A.docx
#
# Base name: 1-HOADON_nhap
#   - 1-HOADON_nhap.doc
#
# Base name: 1-HOADON_nhap Emerson
#   - 1-HOADON_nhap Emerson.doc
#
# Base name: 1-HOADON_nhap Petronas
#   - 1-HOADON_nhap Petronas.doc
#
# Base name: 1-HOADON_nhap Petronas
#   - 1-HOADON_nhap Petronas .doc
#
# Base name: 1-HOADON_nhap Petronas - Service 2
#   - 1-HOADON_nhap Petronas - Service 2.doc
#
# Base name: 1-HOADON_nhap Petronas - antennas
#   - 1-HOADON_nhap Petronas - antennas.doc
#
# Base name: 1-HOADON_nhap Petronas - hang hoa
#   - 1-HOADON_nhap Petronas - hang hoa.doc
#
# Base name: 1. 003 - VIV - S-A form - MS20
#   - 1. 003 - VIV - S-A form - MS20.docx
#
# Base name: 1. 003 - VIV - S-A form - RS20
#   - 1. 003 - VIV - S-A form - RS20.docx
#
# Base name: 1. 003 - VIV - S-A form - Spider
#   - 1. 003 - VIV - S-A form - Spider.docx
#
# Base name: 1. 005 - VIV - S-A form
#   - 1. 005 - VIV - S-A form.docx
#
# Base name: 1. CCTV_Thoa thuan Hop dong
#   - 1. CCTV_Thoa thuan Hop dong.docx
#
# Base name: 1. DKKT CL - FZ-G1 - VIV
#   - 1. DKKT CL - FZ-G1 - VIV.doc
#
# Base name: 1. DKKT CL - VIV
#   - 1. DKKT CL - VIV.doc
#
# Base name: 1. DKKT CL - Vietsov
#   - 1. DKKT CL - Vietsov.doc
#
# Base name: 1. Don Dang ky KT CL - VIV
#   - 1. Don Dang ky KT CL - VIV.doc
#
# Base name: 1. FOPP TO SWITCH (1 TO 2) x 1 set
#   - 1. FOPP TO SWITCH (1 TO 2) x 1 set.docx
#
# Base name: 1. FZ-G1 - VIV - S-A form
#   - 1. FZ-G1 - VIV - S-A form.docx
#
# Base name: 1. Minutes of Meeting
#   - 1. Minutes of Meeting.docx
#
# Base name: 1. Trang bìa
#   - 1. Trang bìa.doc
#
# Base name: 1. WIRING TAG_CCTV (From 1 to 2)
#   - 1. WIRING TAG_CCTV (From 1 to 2).docx
#
# Base name: 1. bao cao ap tai
#   - 1. bao cao ap tai.doc
#
# Base name: 1. ĐKKTCL RLX2-IHNF-A
#   - 1. ĐKKTCL RLX2-IHNF-A .docx
#
# Base name: 1. Đơn xin cấp CNHQ RLX2-INHF-A
#   - 1. Đơn xin cấp CNHQ RLX2-INHF-A.docx
#
# Base name: 1.mau 01 Quyet dinh KTSTQ. doc
#   - 1.mau 01 Quyet dinh KTSTQ. doc.doc
#
# Base name: 106_2022_HDMB_123CORP_VECTOR
#   - 106_2022_HDMB_123CORP_VECTOR.doc
#
# Base name: 10_230607_BSR-HSE-PRO-015_F-005_Giay phep van chuyen thiet bi vat tu tai BSR Rev 5_0210
#   - 10_230607_BSR-HSE-PRO-015_F-005_Giay phep van chuyen thiet bi vat tu tai BSR Rev 5_0210.doc
#
# Base name: 113_2017_nd-cp_346246
#   - 113_2017_nd-cp_346246.doc
#
# Base name: 11_230607_BSR-HSE-PRO-015_F-006_Dang_ky_phuong_tien_giao_thong_vao_nha_may - Rev 5
#   - 11_230607_BSR-HSE-PRO-015_F-006_Dang_ky_phuong_tien_giao_thong_vao_nha_may - Rev 5.docx
#
# Base name: 11_230607_BSR-HSE-PRO-015_F-006_Dang_ky_phuong_tien_giao_thong_vao_nha_may - Rev 5_0210
#   - 11_230607_BSR-HSE-PRO-015_F-006_Dang_ky_phuong_tien_giao_thong_vao_nha_may - Rev 5_0210.docx
#
# Base name: 13. Thong bao phe duyet khai bao van chuyen
#   - 13. Thong bao phe duyet khai bao van chuyen.doc
#
# Base name: 14. Thong bao phe duyet lai khai bao van chuyen
#   - 14. Thong bao phe duyet lai khai bao van chuyen.doc
#
# Base name: 16-0010_Vector Infotech_LCD DELL  Cisco Router_04-2016
#   - 16-0010_Vector Infotech_LCD DELL  Cisco Router_04-2016.doc
#
# Base name: 16-0042_Vector Infotech_Cisco Switch_11-2016 - Revised
#   - 16-0042_Vector Infotech_Cisco Switch_11-2016 - Revised.doc
#
# Base name: 1603008-Contract-TANTIEN_VIVN-150316(rev1)
#   - 1603008-Contract-TANTIEN_VIVN-150316(rev1).doc
#
# Base name: 171207 - draft bien ban phat giao hang cham - rev 1
#   - 171207 - draft bien ban phat giao hang cham - rev 1.docx
#
# Base name: 180525 - Document transmittal
#   - 180525 - Document transmittal.docx
#
# Base name: 195363-VXM-06-LS-7604_CP
#   - 195363-VXM-06-LS-7604_CP.doc
#
# Base name: 195363-VXM-06-QC-7610_CP
#   - 195363-VXM-06-QC-7610_CP.doc
#
# Base name: 195363-VXM-06-QC-7620_CP
#   - 195363-VXM-06-QC-7620_CP.doc
#
# Base name: 195363-VXM-06-QC-7621_CP
#   - 195363-VXM-06-QC-7621_CP.doc
#
# Base name: 195363-VXM-06-QC-7622_CP
#   - 195363-VXM-06-QC-7622_CP.doc
#
# Base name: 195363-VXM-06-QC-7623_CP
#   - 195363-VXM-06-QC-7623_CP.doc
#
# Base name: 195363-VXM-06-QC-7623_CP - Copy
#   - 195363-VXM-06-QC-7623_CP - Copy.doc
#
# Base name: 195363-VXM-06-RP-7604_CP
#   - 195363-VXM-06-RP-7604_CP.doc
#
# Base name: 2. CCTV_Cac dieu kien cua Hop dong_Checked_cleaned
#   - 2. CCTV_Cac dieu kien cua Hop dong_Checked_cleaned.docx
#
# Base name: 2. Decision
#   - 2. Decision.docx
#
# Base name: 2. PO
#   - 2. PO.docx
#
# Base name: 2. UPSC - Ver#1
#   - 2. UPSC - Ver#1.doc
#
# Base name: 2. UTTP TO 8-PORT SWITCH (1 TO 2) - x 23 set
#   - 2. UTTP TO 8-PORT SWITCH (1 TO 2) - x 23 set .docx
#
# Base name: 2. WIRING TAG_CCTV (To 2 from 1)
#   - 2. WIRING TAG_CCTV (To 2 from 1).docx
#
# Base name: 2.mau 02 THONG BAO thu thap TT
#   - 2.mau 02 THONG BAO thu thap TT.doc
#
# Base name: 20-0011_Vector Infotech_Cisco Router 2911_09-2020
#   - 20-0011_Vector Infotech_Cisco Router 2911_09-2020.doc
#
# Base name: 2014-4976-4W-0301 Rev B Material requisition for PAGA system
#   - 2014-4976-4W-0301 Rev B Material requisition for PAGA system.docx
#
# Base name: 2014-4976-4W-0301 Rev.C Material requisition for PAGA system
#   - 2014-4976-4W-0301 Rev.C Material requisition for PAGA system.docx
#
# Base name: 2019_NEXTGEN-VECTOR_Provision of Flame Detector_Rev A
#   - 2019_NEXTGEN-VECTOR_Provision of Flame Detector_Rev A.doc
#
# Base name: 2020-07-24 MẪU GIẤY YCBH AIR_VECTOR INFOTECH
#   - 2020-07-24 MẪU GIẤY YCBH AIR_VECTOR INFOTECH.doc
#
# Base name: 2020-08-17 MẪU GIẤY YCBH AIR_VECTOR INFOTECH
#   - 2020-08-17 MẪU GIẤY YCBH AIR_VECTOR INFOTECH.doc
#
# Base name: 2021 HHNK P001763_VECTOR_USA (002)
#   - 2021 HHNK P001763_VECTOR_USA (002).doc
#
# Base name: 2021-07-09 CÔNG VĂN CAM KẾT
#   - 2021-07-09 CÔNG VĂN CAM KẾT.doc
#
# Base name: 2022-10-18 Hợp đồng mua bán thiết bị điện
#   - 2022-10-18 Hợp đồng mua bán thiết bị điện.doc
#
# Base name: 2023 05 12_C32_HHVC_VECTOR
#   - 2023 05 12_C32_HHVC_VECTOR.doc
#
# Base name: 2023 05 12_C32_HHVC_VECTOR.cmt
#   - 2023 05 12_C32_HHVC_VECTOR.cmt.doc
#
# Base name: 2023 10 04 HD thiet bi GW Vector-NDG - rv1
#   - 2023 10 04 HD thiet bi GW Vector-NDG - rv1.doc
#
# Base name: 2023 HHNK PC00628_USA_AIR CPN.cmt
#   - 2023 HHNK PC00628_USA_AIR CPN.cmt.doc
#
# Base name: 2023 VCND PC00072
#   - 2023 VCND PC00072.doc
#
# Base name: 2023-Muc Luc Ho Son Ban Le va Dich Vu
#   - 2023-Muc Luc Ho Son Ban Le va Dich Vu.docx
#
# Base name: 2024 10 09 HD thiet bi OpenScape Vector-NDG - chia bill
#   - 2024 10 09 HD thiet bi OpenScape Vector-NDG - chia bill.doc
#
# Base name: 2024 10 09 HD thiet bi OpenScape Vector-NDG - rv1-final
#   - 2024 10 09 HD thiet bi OpenScape Vector-NDG - rv1-final.doc
#
# Base name: 2024 HHNK PC00043_UK_AIR (002)cmt
#   - 2024 HHNK PC00043_UK_AIR (002)cmt.doc
#
# Base name: 20242602-HDKT Vector InfoTech -TMG (CISCO )
#   - 20242602-HDKT Vector InfoTech -TMG (CISCO ).doc
#
# Base name: 2104022-01-VECTOR-TK
#   - 2104022-01-VECTOR-TK.docx
#
# Base name: 24-0008_Vector Infotech_Cisco Router 2911_06-2024
#   - 24-0008_Vector Infotech_Cisco Router 2911_06-2024.doc
#
# Base name: 251121 - Contract Amendment No 01 - COVID 19 Expense - 016E
#   - 251121 - Contract Amendment No 01 - COVID 19 Expense - 016E.doc
#
# Base name: 3.  Bank Account confirmed by Tax office
#   - 3.  Bank Account confirmed by Tax office.doc
#
# Base name: 3. 5. Busniess license translated
#   - 3. 5. Busniess license translated.docx
#
# Base name: 3. Chap nhan BT va chuyển quyền khiếu nại _VECTOR PC00738
#   - 3. Chap nhan BT va chuyển quyền khiếu nại _VECTOR PC00738.doc
#
# Base name: 3. Hop dong-ghi am dien thoi
#   - 3. Hop dong-ghi am dien thoi.docx
#
# Base name: 3. Notice_business line
#   - 3. Notice_business line.doc
#
# Base name: 3. UTTP TO 16-PORT SWITCH (1 TO 2) - x 2 set
#   - 3. UTTP TO 16-PORT SWITCH (1 TO 2) - x 2 set.docx
#
# Base name: 3.1 MOM - Vector Infotech
#   - 3.1 MOM - Vector Infotech.doc
#
# Base name: 3.1. CCTV_Phu luc 1 - Pham vi cong viec
#   - 3.1. CCTV_Phu luc 1 - Pham vi cong viec.docx
#
# Base name: 3.1. MOM - Vector Infotech - Attachment
#   - 3.1. MOM - Vector Infotech - Attachment.docx
#
# Base name: 3.1.1 CCTV_Attachment #1-Detail Scope of Work
#   - 3.1.1 CCTV_Attachment #1-Detail Scope of Work.doc
#
# Base name: 3.1.2 CCTV_Attachment #2-Interface
#   - 3.1.2 CCTV_Attachment #2-Interface.docx
#
# Base name: 3.2. CCTV_Phu luc 2_Dieu khoan va quy trinh thanh toan_Checked_cleaned
#   - 3.2. CCTV_Phu luc 2_Dieu khoan va quy trinh thanh toan_Checked_cleaned.docx
#
# Base name: 3.5. CCTV_Phu luc 5. Bieu mau
#   - 3.5. CCTV_Phu luc 5. Bieu mau.doc
#
# Base name: 3.mau 03 Quyet dinh sưa doi bo sung QD KTSTQ.3
#   - 3.mau 03 Quyet dinh sưa doi bo sung QD KTSTQ.3.doc
#
# Base name: 30.2011.TT.BTTTT
#   - 30.2011.TT.BTTTT.doc
#
# Base name: 30_2011_TT-BTTTT[1]
#   - 30_2011_TT-BTTTT[1].doc
#
# Base name: 4  Don van chuyen - done (2)
#   - 4  Don van chuyen - done (2).doc
#
# Base name: 4. Att. 2 - Packing and Marking -VAT with PO No
#   - 4. Att. 2 - Packing and Marking -VAT with PO No.docx
#
# Base name: 4. HD UY THAC PVEPPOC
#   - 4. HD UY THAC PVEPPOC.doc
#
# Base name: 4. Mẫu CV đăng ký dấu hợp quy_Cuc Vien thong (Form mới)
#   - 4. Mẫu CV đăng ký dấu hợp quy_Cuc Vien thong (Form mới).doc
#
# Base name: 4. Power of attorney
#   - 4. Power of attorney.doc
#
# Base name: 4. SBP_HOP DONG M&E ISD
#   - 4. SBP_HOP DONG M&E ISD.doc
#
# Base name: 4. SBP_HOP DONG M&E ISD Feb 3 2021
#   - 4. SBP_HOP DONG M&E ISD Feb 3 2021.doc
#
# Base name: 4. SBP_HOP DONG M&E NHÃ_P
#   - 4. SBP_HOP DONG M&E NHÃ_P.doc
#
# Base name: 4. Sample RLX2-IHNF-A
#   - 4. Sample RLX2-IHNF-A.docx
#
# Base name: 4.mau 04 quyet dinh gia han.4
#   - 4.mau 04 quyet dinh gia han.4.doc
#
# Base name: 466 Vector InfoTech - Digital Pressure Gauge XP2i-cmt
#   - 466 Vector InfoTech - Digital Pressure Gauge XP2i-cmt.docx
#
# Base name: 5. BẢN ẢNH MÔ TẢ DÁN NHÃN HÀNG HÓA MÁY TÍNH BẢNG FZ
#   - 5. BẢN ẢNH MÔ TẢ DÁN NHÃN HÀNG HÓA MÁY TÍNH BẢNG FZ.doc
#
# Base name: 5. GIAY GIOI THIEU VECTOR
#   - 5. GIAY GIOI THIEU VECTOR.doc
#
# Base name: 5. UTTP TO SWITCH (1 TO 2) - Admin - 2F x 1 set
#   - 5. UTTP TO SWITCH (1 TO 2) - Admin - 2F x 1 set.docx
#
# Base name: 5. VC_SEHC to SS partners_2023_Revised by RM & Legal_Final version_June 6
#   - 5. VC_SEHC to SS partners_2023_Revised by RM & Legal_Final version_June 6.docx
#
# Base name: 5.mau 05 Ban KLKT
#   - 5.mau 05 Ban KLKT.doc
#
# Base name: 58- Mẫu 4 - Đơn xin cấp GPNK
#   - 58- Mẫu 4 - Đơn xin cấp GPNK.docx
#
# Base name: 580-Contract-HoangLe_VIVN-Westermo-160915
#   - 580-Contract-HoangLe_VIVN-Westermo-160915.docx
#
# Base name: 5825_TCHQ-GSQL_497363
#   - 5825_TCHQ-GSQL_497363.doc
#
# Base name: 58_2016_ND-CP
#   - 58_2016_ND-CP.doc
#
# Base name: 6  HD contract
#   - 6  HD contract .doc
#
# Base name: 6. GIAY GIOI THIEU Vector
#   - 6. GIAY GIOI THIEU Vector.DOC
#
# Base name: 6. UTTP TO SWITCH (1 TO 2) - Admin - GF x 1 set
#   - 6. UTTP TO SWITCH (1 TO 2) - Admin - GF x 1 set.docx
#
# Base name: 6.Mau 06 thong bao ket qua kiem tra.QT
#   - 6.Mau 06 thong bao ket qua kiem tra.QT.doc
#
# Base name: 640-Contract-Sytek_VIVN-Westermo-190416
#   - 640-Contract-Sytek_VIVN-Westermo-190416.docx
#
# Base name: 6_230607_BSR-HSE-PRO-015_F-001_Dang_ky yeu cau vao Nha may - Rev 5_0210
#   - 6_230607_BSR-HSE-PRO-015_F-001_Dang_ky yeu cau vao Nha may - Rev 5_0210.doc
#
# Base name: 7  Bien_ban_dam_phan - A
#   - 7  Bien_ban_dam_phan - A.DOC
#
# Base name: 7-2020-06-15-pl-vii-mau-loi-van-khai-bao-xuat-xu-clean-version
#   - 7-2020-06-15-pl-vii-mau-loi-van-khai-bao-xuat-xu-clean-version.docx
#
# Base name: 7. UTTP TO SWITCH (1 TO 2) - CCB x 1 set
#   - 7. UTTP TO SWITCH (1 TO 2) - CCB x 1 set.docx
#
# Base name: 7.mau 07 QD HUY  kiem tra.9
#   - 7.mau 07 QD HUY  kiem tra.9.doc
#
# Base name: 75-LuậtTiêu chuẩn,Quy chuẩn KT
#   - 75-LuậtTiêu chuẩn,Quy chuẩn KT.DOC
#
# Base name: 786a5340-38eb-4978-aed2-0b6388a446f0
#   - 786a5340-38eb-4978-aed2-0b6388a446f0.docx
#
# Base name: 8 HOP DONG- DH 636 (sửa tk bank ngày 1708)
#   - 8 HOP DONG- DH 636 (sửa tk bank ngày 1708).doc
#
# Base name: 8. Hợp đồng đh 203 (Phần 1 - Vector Infotech) draft
#   - 8. Hợp đồng đh 203 (Phần 1 - Vector Infotech) draft.docx
#
# Base name: 8.Mau 08 BB kiêm tra.8
#   - 8.Mau 08 BB kiêm tra.8.doc
#
# Base name: 9.Mau 09 CONG BO QD kiem tra
#   - 9.Mau 09 CONG BO QD kiem tra.doc
#
# Base name: 94_2023_ND-CP_589156
#   - 94_2023_ND-CP_589156.doc
#
# Base name: A20150700-009
#   - A20150700-009.doc
#
# Base name: ACCEPTANCE PROTOCOL_FINAL
#   - ACCEPTANCE PROTOCOL_FINAL.doc
#
# Base name: AFS-09501E Warranty Claim_Return_Repair form - RMA rev6
#   - AFS-09501E Warranty Claim_Return_Repair form - RMA rev6.doc
#
# Base name: AFS-09501E Warranty Claim_Return_Repair form - RMA rev8
#   - AFS-09501E Warranty Claim_Return_Repair form - RMA rev8.doc
#
# Base name: ANNEX PO-20-0157
#   - ANNEX PO-20-0157.docx
#
# Base name: AOF Template Rev 10-2021
#   - AOF Template Rev 10-2021.docx
#
# Base name: APPENDIX
#   - APPENDIX.docx
#
# Base name: APPENDIX 01_PO 0006_TELECOM
#   - APPENDIX 01_PO 0006_TELECOM.doc
#
# Base name: APPENDIX 01_PO 0006_TELECOM Rev
#   - APPENDIX 01_PO 0006_TELECOM Rev.doc
#
# Base name: APPENDIX 01_PO 0006_TELECOM_Vector updated 14 Feb 2015 rev by VIT
#   - APPENDIX 01_PO 0006_TELECOM_Vector updated 14 Feb 2015 rev by VIT.doc
#
# Base name: APPENDIX 01_PO 0006_TELECOM_Vector updated 27 Feb 2015 Final
#   - APPENDIX 01_PO 0006_TELECOM_Vector updated 27 Feb 2015 Final.doc
#
# Base name: APPENDIX No 3 - Final Acceptance Protocol
#   - APPENDIX No 3 - Final Acceptance Protocol.doc
#
# Base name: Agreement of Joint Venture (Tzone - Vector)  Rev 3 Dec 18
#   - Agreement of Joint Venture (Tzone - Vector)  Rev 3 Dec 18.doc
#
# Base name: Agreement_ Demo
#   - Agreement_ Demo.docx
#
# Base name: Agreement_ Quality Test
#   - Agreement_ Quality Test.docx
#
# Base name: Andrew Telecommunication Systems US
#   - Andrew Telecommunication Systems US.docx
#
# Base name: Annex - Autronica
#   - Annex - Autronica.docx
#
# Base name: Annex - Det-tronics
#   - Annex - Det-tronics.docx
#
# Base name: AnnexA_Datasheet
#   - AnnexA_Datasheet.docx
#
# Base name: AnnexB_demo schedule
#   - AnnexB_demo schedule.docx
#
# Base name: Att 4 - Shipping instruction for group C & D
#   - Att 4 - Shipping instruction for group C & D.doc
#
# Base name: Att 5 - Shipping instruction for group C & D
#   - Att 5 - Shipping instruction for group C & D.doc
#
# Base name: Att 6b - Warranty Bond Draft
#   - Att 6b - Warranty Bond Draft.doc
#
# Base name: Attachment 1 - Vendor Information Form for Type 1-3
#   - Attachment 1 - Vendor Information Form for Type 1-3.docx
#
# Base name: Attachment 5-Delivery Cert
#   - Attachment 5-Delivery Cert.doc
#
# Base name: AutroPoint HC200 Datasheet VN (1)
#   - AutroPoint HC200 Datasheet VN (1).docx
#
# Base name: BB DAM PHAN GIAM GIA PO 0006 10-8-15 Ngoc bổ sung
#   - BB DAM PHAN GIAM GIA PO 0006 10-8-15 Ngoc bổ sung.doc
#
# Base name: BB DAM PHAN GIAM GIA PO 0006 21-8-15 final commented by Vector
#   - BB DAM PHAN GIAM GIA PO 0006 21-8-15 final commented by Vector.doc
#
# Base name: BB DAO TAO CNSG
#   - BB DAO TAO CNSG.docx
#
# Base name: BB HOP ngay 4-12-2014
#   - BB HOP ngay 4-12-2014.doc
#
# Base name: BB HOP ngay 4-12-2014 VN
#   - BB HOP ngay 4-12-2014 VN.doc
#
# Base name: BB giao nhận tạm hàng hóa HĐ 368-2-19 -CNTT-VECTOR (1)
#   - BB giao nhận tạm hàng hóa HĐ 368-2-19 -CNTT-VECTOR (1).doc
#
# Base name: BB lam viec voi Fedex - vv mat hang Dettronics
#   - BB lam viec voi Fedex - vv mat hang Dettronics.doc
#
# Base name: BB lam viec voi Fedex - vv mat hang Ziztel
#   - BB lam viec voi Fedex - vv mat hang Ziztel.doc
#
# Base name: BB nghiem thu cong viec cai dat, chay thu
#   - BB nghiem thu cong viec cai dat, chay thu.doc
#
# Base name: BBKH-150801-03-STT-PTSC-VIVN-MEDC-  Rev 1
#   - BBKH-150801-03-STT-PTSC-VIVN-MEDC-  Rev 1.docx
#
# Base name: BBKH-150801-05-STT-PTSC-VIVN Beacon via Seagull
#   - BBKH-150801-05-STT-PTSC-VIVN Beacon via Seagull.docx
#
# Base name: BBKH-150801-06-Alphino
#   - BBKH-150801-06-Alphino.docx
#
# Base name: BBKH-50801-09-STT-PTSC-VIVN JB via CP Tech
#   - BBKH-50801-09-STT-PTSC-VIVN JB via CP Tech.docx
#
# Base name: BBTL
#   - BBTL.docx
#
# Base name: BBTL HD CCTV
#   - BBTL HD CCTV.doc
#
# Base name: BBTL HD InnovA
#   - BBTL HD InnovA.doc
#
# Base name: BBTL HD VIMAS TVT UPs & Camera
#   - BBTL HD VIMAS TVT UPs & Camera.doc
#
# Base name: BD-HSE-P-0029 F1 Khai báo thông tin
#   - BD-HSE-P-0029 F1 Khai báo thông tin.docx
#
# Base name: BD-HSE-P-0029 F1 Khai báo thông tin Trần Huỳnh Quang
#   - BD-HSE-P-0029 F1 Khai báo thông tin Trần Huỳnh Quang.docx
#
# Base name: BD-OPS-2014-099A - Vector Infotech
#   - BD-OPS-2014-099A - Vector Infotech.docx
#
# Base name: BD-OPS-2014-099A - Vector Infotech Request for Payment
#   - BD-OPS-2014-099A - Vector Infotech Request for Payment.docx
#
# Base name: BD-OPS-2015-109B - Vector Infotech Draft PO
#   - BD-OPS-2015-109B - Vector Infotech Draft PO.docx
#
# Base name: BD-OPS-2020-081A - Vector Infotech-commented
#   - BD-OPS-2020-081A - Vector Infotech-commented.docx
#
# Base name: BD-OPS-2021-025A - Vector Infotech
#   - BD-OPS-2021-025A - Vector Infotech.docx
#
# Base name: BELDEN Confirmation Letter
#   - BELDEN Confirmation Letter.docx
#
# Base name: BELDEN draft certs
#   - BELDEN draft certs.docx
#
# Base name: BIÊN BẢN XÁC NHẬN HOÀN THÀNH CÔNG VIỆC
#   - BIÊN BẢN XÁC NHẬN HOÀN THÀNH CÔNG VIỆC.docx
#
# Base name: BL Instructions
#   - BL Instructions.docx
#
# Base name: BL THHĐ
#   - BL THHĐ.docx
#
# Base name: BM 01 8a GQKN -  Thong bao ton that_12 2012
#   - BM 01 8a GQKN -  Thong bao ton that_12 2012.doc
#
# Base name: BM 17 02 TM - Bao lanh Thuc hien Hop dong VN - final
#   - BM 17 02 TM - Bao lanh Thuc hien Hop dong VN - final.doc
#
# Base name: BM.01.8a.GQKN -  Vector - 11-10-16
#   - BM.01.8a.GQKN -  Vector - 11-10-16.doc
#
# Base name: BMHD 01 3a KTBH_YCBH hang hoa__22.3.2012
#   - BMHD 01 3a KTBH_YCBH hang hoa__22.3.2012.doc
#
# Base name: BOM VSP-BK20 Radio
#   - BOM VSP-BK20 Radio.docx
#
# Base name: BOUNMYXAY HOTEL
#   - BOUNMYXAY HOTEL.docx
#
# Base name: BSR-000-045_F-001
#   - BSR-000-045_F-001.doc
#
# Base name: Ban cam ket - for contractor
#   - Ban cam ket - for contractor .docx
#
# Base name: Ban khai 1G GPTS Intel VN_2018 04 17 ok
#   - Ban khai 1G GPTS Intel VN_2018 04 17 ok.doc
#
# Base name: Bao cao - Co so xuat nhap khau nguon phong xa 2017
#   - Bao cao - Co so xuat nhap khau nguon phong xa 2017.docx
#
# Base name: Bao lanh thanh toan Vector
#   - Bao lanh thanh toan Vector.docx
#
# Base name: Belden Mooresville
#   - Belden Mooresville.docx
#
# Base name: Belden_Changing origin SFP
#   - Belden_Changing origin SFP.docx
#
# Base name: Bia muc luc ho so
#   - Bia muc luc ho so.docx
#
# Base name: Bien Ban Dieu Chinh
#   - Bien Ban Dieu Chinh.doc
#
# Base name: Bien Ban Dieu Chinh final
#   - Bien Ban Dieu Chinh final.doc
#
# Base name: Bien ban dam phan - 1417DGCPXNK
#   - Bien ban dam phan - 1417DGCPXNK.doc
#
# Base name: Bien ban thanh lý hợp đồng 485-2021HĐ-BSR-INFOTECH rev1
#   - Bien ban thanh lý hợp đồng 485-2021HĐ-BSR-INFOTECH rev1.DOC
#
# Base name: Bien ban thanh lý hợp đồng 485-2021HĐ-BSR-INFOTECH-final
#   - Bien ban thanh lý hợp đồng 485-2021HĐ-BSR-INFOTECH-final.doc
#
# Base name: Bitrix Manual
#   - Bitrix Manual.docx
#
# Base name: Biên bản Kiểm tra Hàng hóa Eltron for Khanh Gia
#   - Biên bản Kiểm tra Hàng hóa Eltron for Khanh Gia.docx
#
# Base name: Biên bản Kiểm tra Hàng hóa F5 for Hanwha Life
#   - Biên bản Kiểm tra Hàng hóa F5 for Hanwha Life.docx
#
# Base name: Biên bản Kiểm tra Hàng hóa Hirschmann for ABB
#   - Biên bản Kiểm tra Hàng hóa Hirschmann for ABB.docx
#
# Base name: Biên bản Kiểm tra Hàng hóa Hirschmann for Galaxy
#   - Biên bản Kiểm tra Hàng hóa Hirschmann for Galaxy.docx
#
# Base name: Biên bản Kiểm tra Hàng hóa Motorola  for Bien Dong
#   - Biên bản Kiểm tra Hàng hóa Motorola  for Bien Dong.docx
#
# Base name: Biên bản Kiểm tra Hàng hóa Nội bộ
#   - Biên bản Kiểm tra Hàng hóa Nội bộ.docx
#
# Base name: Biên bản Kiểm tra Hàng hóa Televes for Bien Dong
#   - Biên bản Kiểm tra Hàng hóa Televes for Bien Dong.docx
#
# Base name: Biên bản Kiểm tra Hàng hóa Vtech for Khanh Gia
#   - Biên bản Kiểm tra Hàng hóa Vtech for Khanh Gia.docx
#
# Base name: Biên bản nghiệm thu hoàn thành chạy thử
#   - Biên bản nghiệm thu hoàn thành chạy thử.doc
#
# Base name: Biên bản nghiệm thu hoàn thành chạy thử-R1
#   - Biên bản nghiệm thu hoàn thành chạy thử-R1.doc
#
# Base name: Biên bản nghiệm thu khối lượng công việc KCQ-revised
#   - Biên bản nghiệm thu khối lượng công việc KCQ-revised.doc
#
# Base name: Biên-bản-trả-lại-hàng
#   - Biên-bản-trả-lại-hàng.doc
#
# Base name: Bo sung 01_PO 0006 (002)
#   - Bo sung 01_PO 0006 (002).doc
#
# Base name: Bo sung 02_PO 0006
#   - Bo sung 02_PO 0006.doc
#
# Base name: Budgetary Offer - CCTV
#   - Budgetary Offer - CCTV.doc
#
# Base name: Budgetary Offer - IPCO
#   - Budgetary Offer - IPCO.doc
#
# Base name: Báo cáo đánh giá - Thiết bị áp lực
#   - Báo cáo đánh giá - Thiết bị áp lực.docx
#
# Base name: Báo giá Công ty Anh Phương
#   - Báo giá Công ty Anh Phương.doc
#
# Base name: Báo giá ổ cứng CT Vector Infotech
#   - Báo giá ổ cứng CT Vector Infotech.docx
#
# Base name: Bảo hiểm hàng hóa
#   - Bảo hiểm hàng hóa.doc
#
# Base name: C..._HHVC_VECTOR
#   - C..._HHVC_VECTOR.doc
#
# Base name: CACH TRA HS CODE
#   - CACH TRA HS CODE.docx
#
# Base name: CI export
#   - CI export.docx
#
# Base name: CI- export-Product
#   - CI- export-Product.docx
#
# Base name: CI- export-Service
#   - CI- export-Service.docx
#
# Base name: CI-PL export to DET
#   - CI-PL export to DET.docx
#
# Base name: CI-PL export to Myanmar
#   - CI-PL export to Myanmar.docx
#
# Base name: CI-PL import
#   - CI-PL import.docx
#
# Base name: CI-SM1603001-Samlex - 1st Shipment - Copy
#   - CI-SM1603001-Samlex - 1st Shipment - Copy.docx
#
# Base name: CMH-005-6 -E-mail address information
#   - CMH-005-6 -E-mail address information.doc
#
# Base name: CO revised
#   - CO revised.docx
#
# Base name: CO,CQQ-Fandis
#   - CO,CQQ-Fandis.docx
#
# Base name: COC - VIT Belden Cable
#   - COC - VIT Belden Cable.docx
#
# Base name: COC VECTOR INFO TECH 23423976 RSK
#   - COC VECTOR INFO TECH 23423976 RSK.doc
#
# Base name: CONG VAN DE NGHI muon CO GOC
#   - CONG VAN DE NGHI muon CO GOC.doc
#
# Base name: CONG VAN GIAI TRINH MMDS
#   - CONG VAN GIAI TRINH MMDS.doc
#
# Base name: CONG VAN TAI NHAP VECTOR-Telesupply
#   - CONG VAN TAI NHAP VECTOR-Telesupply.doc
#
# Base name: CONG VAN TAI XUAT
#   - CONG VAN TAI XUAT.docx
#
# Base name: CONG VAN TAM NHAP VECTOR
#   - CONG VAN TAM NHAP VECTOR.doc
#   - CONG VAN TAM NHAP VECTOR.docx
#
# Base name: CONG VAN TAM NHAP VECTOR_cmt
#   - CONG VAN TAM NHAP VECTOR_cmt.doc
#
# Base name: CONG VAN TAM XUAT Jurong
#   - CONG VAN TAM XUAT Jurong.doc
#
# Base name: CONG VAN TAM XUAT VECTOR-Telesupply
#   - CONG VAN TAM XUAT VECTOR-Telesupply.doc
#
# Base name: CONG VAN TAM XUAT Vector Ziztel
#   - CONG VAN TAM XUAT Vector Ziztel.doc
#
# Base name: CONG VAN XIN GIA HAN HD
#   - CONG VAN XIN GIA HAN HD.doc
#
# Base name: CONG VAN XN mất hàng Det- Fedex Det Tronics ND sửa
#   - CONG VAN XN mất hàng Det- Fedex Det Tronics ND sửa.doc
#
# Base name: CONTRACT 1.1.1
#   - CONTRACT 1.1.1.docx
#
# Base name: CONTRACT 1.1.1 (002) Draft Long Phu
#   - CONTRACT 1.1.1 (002) Draft Long Phu.docx
#
# Base name: CONTRACT 1.1.1 (002) Draft Long Phu Filled with comments
#   - CONTRACT 1.1.1 (002) Draft Long Phu Filled with comments.docx
#
# Base name: CONTRACT VXM - VECTOR HQC - INDOOR (20 05.21) VIT
#   - CONTRACT VXM - VECTOR HQC - INDOOR (20 05.21) VIT.docx
#
# Base name: CONTRACT VXM - VECTOR HQC - INDOOR 11 June  VIT
#   - CONTRACT VXM - VECTOR HQC - INDOOR 11 June  VIT.doc
#
# Base name: CONTRACT-Telecom System rev 20141022-FINAL
#   - CONTRACT-Telecom System rev 20141022-FINAL.doc
#
# Base name: COO 29.04.16
#   - COO 29.04.16.doc
#
# Base name: COO VECTOR 23423976 RSK
#   - COO VECTOR 23423976 RSK.doc
#
# Base name: COO-Ban dich
#   - COO-Ban dich.docx
#
# Base name: CQ Format
#   - CQ Format.docx
#
# Base name: CQ Samlex
#   - CQ Samlex.docx
#
# Base name: CQ Samlex final
#   - CQ Samlex final.docx
#
# Base name: CQ Samlex-revised (final)
#   - CQ Samlex-revised (final).docx
#
# Base name: CQ TZone M1  Jan 24 2018
#   - CQ TZone M1  Jan 24 2018.doc
#
# Base name: CQQ - M1 8MM SC
#   - CQQ - M1 8MM SC.docx
#
# Base name: CQQ - MACH 102 Switch
#   - CQQ - MACH 102 Switch.docx
#
# Base name: CQQ - draft
#   - CQQ - draft.docx
#
# Base name: CQQ 3 mục
#   - CQQ 3 mục.docx
#
# Base name: CQQ sample - unsign
#   - CQQ sample - unsign.docx
#
# Base name: CQQ-Meanwell
#   - CQQ-Meanwell.docx
#
# Base name: CRM SUPPLIER RANKING PLAN
#   - CRM SUPPLIER RANKING PLAN.docx
#
# Base name: CT1811047 - Autronica for Bao Nghi
#   - CT1811047 - Autronica for Bao Nghi.docx
#
# Base name: CT1812052 - WARRANTY
#   - CT1812052 - WARRANTY.docx
#
# Base name: CT18903011 - Thong tin hàng
#   - CT18903011 - Thong tin hàng.docx
#
# Base name: CT2009054 - Cong van de nghi ho tro doanh nghiep
#   - CT2009054 - Cong van de nghi ho tro doanh nghiep.doc
#
# Base name: CT2307040-Cong van nhac no thanh toan
#   - CT2307040-Cong van nhac no thanh toan.doc
#
# Base name: CT2403020-Cong van nhac no thanh toan
#   - CT2403020-Cong van nhac no thanh toan.doc
#
# Base name: CT2403020-Cong van yeu cau thanh toan dung han_310724
#   - CT2403020-Cong van yeu cau thanh toan dung han_310724.doc
#
# Base name: CT2405028-SI-XN_pbh
#   - CT2405028-SI-XN_pbh.docx
#
# Base name: CV (Toan)
#   - CV (Toan).docx
#
# Base name: CV 10012023 Yêu cầu TT đúng hạn SH
#   - CV 10012023 Yêu cầu TT đúng hạn SH.doc
#
# Base name: CV 1908054 - CV cam ket
#   - CV 1908054 - CV cam ket.doc
#
# Base name: CV 2307040 Yeu cau thanh toan dung han
#   - CV 2307040 Yeu cau thanh toan dung han.doc
#
# Base name: CV 2310065-01 - TAX
#   - CV 2310065-01 - TAX.docx
#
# Base name: CV 2310065-01-Quota-V
#   - CV 2310065-01-Quota-V.docx
#
# Base name: CV BO SUNG HO SO NK
#   - CV BO SUNG HO SO NK.docx
#
# Base name: CV GHTGGH
#   - CV GHTGGH.docx
#
# Base name: CV Gửi NH NN TT số 32
#   - CV Gửi NH NN TT số 32.docx
#
# Base name: CV OB 141201- Vietso WIP 40 k ddt  Jan 12
#   - CV OB 141201- Vietso WIP 40 k ddt  Jan 12.docx
#
# Base name: CV OB 150103- Vietso WIP 40 k ddt  April 20 2015 Delivery Notice
#   - CV OB 150103- Vietso WIP 40 k ddt  April 20 2015 Delivery Notice.docx
#
# Base name: CV OB 150103- Vietso WIP 40 k ddt  May 12 Xin phep gia han HD
#   - CV OB 150103- Vietso WIP 40 k ddt  May 12 Xin phep gia han HD.docx
#
# Base name: CV OB 150103- Vietso WIP 40 k ddt  May 20 2015
#   - CV OB 150103- Vietso WIP 40 k ddt  May 20 2015.docx
#
# Base name: CV OB150103-09 - Sai khac serial number
#   - CV OB150103-09 - Sai khac serial number.docx
#
# Base name: CV OB150103-09 - Sai khac serial number Rev 1
#   - CV OB150103-09 - Sai khac serial number Rev 1.docx
#
# Base name: CV OB150201 -02 to VSP Dai Hung Gas -Additional Scope of Work clarification-revised
#   - CV OB150201 -02 to VSP Dai Hung Gas -Additional Scope of Work clarification-revised.docx
#
# Base name: CV OB150201-05 to VSP Dai Hung Gas - Equipment Clarification Issue
#   - CV OB150201-05 to VSP Dai Hung Gas - Equipment Clarification Issue.docx
#
# Base name: CV OB150201-05 to VSP Dai Hung Gas - Equipment Clarification Issue DRAFT EN
#   - CV OB150201-05 to VSP Dai Hung Gas - Equipment Clarification Issue DRAFT EN.docx
#
# Base name: CV OB150201-05 to VSP Dai Hung Gas -Giải trình kỹ thuật
#   - CV OB150201-05 to VSP Dai Hung Gas -Giải trình kỹ thuật.docx
#
# Base name: CV OB150201-05 to VSP Dai Hung Gas -Giải trình kỹ thuật Rev 1 Jul 2 VN
#   - CV OB150201-05 to VSP Dai Hung Gas -Giải trình kỹ thuật Rev 1 Jul 2 VN.docx
#
# Base name: CV OB150201-05 to VSP Dai Hung Gas -Giải trình kỹ thuật VNES
#   - CV OB150201-05 to VSP Dai Hung Gas -Giải trình kỹ thuật VNES.docx
#
# Base name: CV OB150201-07 to VSP Dai Hung Gas -Giải trình giao hàng trễ
#   - CV OB150201-07 to VSP Dai Hung Gas -Giải trình giao hàng trễ.doc
#
# Base name: CV OB150201-07 to VSP Dai Hung Gas -Giải trình giao hàng trễ - Copy
#   - CV OB150201-07 to VSP Dai Hung Gas -Giải trình giao hàng trễ - Copy.doc
#
# Base name: CV OB150201-09 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1
#   - CV OB150201-09 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1.doc
#
# Base name: CV OB150201-10 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1
#   - CV OB150201-10 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1.doc
#
# Base name: CV OB150201-11 to VSP Dai Hung Gas -Xuat xu hang hoa-A Tu revised
#   - CV OB150201-11 to VSP Dai Hung Gas -Xuat xu hang hoa-A Tu revised.doc
#
# Base name: CV OB150201-13 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1
#   - CV OB150201-13 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1.doc
#
# Base name: CV OB150201-13 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1- Nguyen revised
#   - CV OB150201-13 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1- Nguyen revised.doc
#
# Base name: CV OB150201-14 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1- VO #3
#   - CV OB150201-14 to VSP Dai Hung Gas -Công việc phát sinh tại ĐH1- VO #3.doc
#
# Base name: CV OB150201-17 to VSP Dai Hung Gas - Bảo hành Thiết bị Router
#   - CV OB150201-17 to VSP Dai Hung Gas - Bảo hành Thiết bị Router.doc
#
# Base name: CV OB150801- STT _ PTSC- NH NN - Sep 2015
#   - CV OB150801- STT _ PTSC- NH NN - Sep 2015.doc
#
# Base name: CV OB151102-01-Rev 1 to VSP-VT293- 23022016
#   - CV OB151102-01-Rev 1 to VSP-VT293- 23022016.docx
#
# Base name: CV OB151102-01-Rev 1 to VSP-VT293- Nguyen revised
#   - CV OB151102-01-Rev 1 to VSP-VT293- Nguyen revised.docx
#
# Base name: CV OB151102-04 to VSP-VT293-Giay phep tan so (2)
#   - CV OB151102-04 to VSP-VT293-Giay phep tan so (2).docx
#
# Base name: CV OB151102-12 to VSP-VT293-Giam gia hop dong- revised
#   - CV OB151102-12 to VSP-VT293-Giam gia hop dong- revised.docx
#
# Base name: CV OB151102-13 to VSP-VT293-Thay doi nam san xuat cua cap - 3%
#   - CV OB151102-13 to VSP-VT293-Thay doi nam san xuat cua cap - 3%.docx
#
# Base name: CV OB151102-13 to VSP-VT293-Thay doi nam san xuat cua cap - Copy (2)
#   - CV OB151102-13 to VSP-VT293-Thay doi nam san xuat cua cap - Copy (2).docx
#
# Base name: CV OB151102-13 to VSP-VT293-Thay doi nam san xuat cua cap - Copy - Copy
#   - CV OB151102-13 to VSP-VT293-Thay doi nam san xuat cua cap - Copy - Copy.docx
#
# Base name: CV SI 171239 - CV Out 01 Petronas Sparepart  Dec 5 2017
#   - CV SI 171239 - CV Out 01 Petronas Sparepart  Dec 5 2017.doc
#
# Base name: CV SI 171239 - CV Out 01 Petronas Sparepart  Dec 5 2017 rev 1
#   - CV SI 171239 - CV Out 01 Petronas Sparepart  Dec 5 2017 rev 1.doc
#
# Base name: CV SI 1909059 - CV Out 01 Petronas Sparepart
#   - CV SI 1909059 - CV Out 01 Petronas Sparepart.doc
#
# Base name: CV SI 1909059_SP_KN
#   - CV SI 1909059_SP_KN.doc
#
# Base name: CV Tai xuat-Engtek Demo-Sin
#   - CV Tai xuat-Engtek Demo-Sin.doc
#
# Base name: CV Tam nhap - Dwisolar
#   - CV Tam nhap - Dwisolar.doc
#
# Base name: CV Tam nhap - Dwisolar ( Updated )
#   - CV Tam nhap - Dwisolar ( Updated ).doc
#
# Base name: CV Tam nhap-Autronica Demo-Malay
#   - CV Tam nhap-Autronica Demo-Malay.doc
#
# Base name: CV Tam nhap-StarCom Demo Sing
#   - CV Tam nhap-StarCom Demo Sing.doc
#
# Base name: CV Tam xuất
#   - CV Tam xuất.doc
#
# Base name: CV VECTOR HQC Thanh toan Moc 1 LNG Thi Vai
#   - CV VECTOR HQC Thanh toan Moc 1 LNG Thi Vai.doc
#
# Base name: CV gửi Cục Viễn thông
#   - CV gửi Cục Viễn thông.doc
#
# Base name: CV khai bao van chuyen -done
#   - CV khai bao van chuyen -done.doc
#
# Base name: CV nhac no lan 1_23.08
#   - CV nhac no lan 1_23.08.doc
#
# Base name: CV phat hop dong
#   - CV phat hop dong.doc
#
# Base name: CV to VSP Dai Hung Gas - Delay Delivery Draft
#   - CV to VSP Dai Hung Gas - Delay Delivery Draft.docx
#
# Base name: CV to VSP Dai Hung Gas - Delivery Notice  June 26 2015
#   - CV to VSP Dai Hung Gas - Delivery Notice  June 26 2015.docx
#
# Base name: CV to VSP Dai Hung Gas - Delivery and FAT Notification-Draft
#   - CV to VSP Dai Hung Gas - Delivery and FAT Notification-Draft.docx
#
# Base name: CV to VSP Dai Hung Gas - Shipping Notification Draft
#   - CV to VSP Dai Hung Gas - Shipping Notification Draft.docx
#
# Base name: CV-SI1603009-Certifiacte - Copy
#   - CV-SI1603009-Certifiacte - Copy.docx
#
# Base name: CV-SI1603009-Certifiacte - Copy -En-revised
#   - CV-SI1603009-Certifiacte - Copy -En-revised.docx
#
# Base name: CV-SI1603009-Certifiacte - Copy -En-revised (2)
#   - CV-SI1603009-Certifiacte - Copy -En-revised (2).docx
#
# Base name: CV-SI1603009-Certifiacte - Copy-
#   - CV-SI1603009-Certifiacte - Copy-.docx
#
# Base name: CV190409 - to Dinh Co
#   - CV190409 - to Dinh Co.doc
#
# Base name: CV2007 -BDPOC
#   - CV2007 -BDPOC.doc
#
# Base name: CV200825 -BDPOC
#   - CV200825 -BDPOC.doc
#
# Base name: CV2310059 tien do giao hang
#   - CV2310059 tien do giao hang.doc
#
# Base name: CVMMDS_21_04
#   - CVMMDS_21_04.docx
#
# Base name: CW 2310065 - warranty confirmation
#   - CW 2310065 - warranty confirmation.docx
#
# Base name: CW1810043 - Emerson
#   - CW1810043 - Emerson.docx
#
# Base name: CW1810043 - Emerson - Splicing
#   - CW1810043 - Emerson - Splicing.docx
#
# Base name: CW1810045 - TLJOC
#   - CW1810045 - TLJOC.docx
#
# Base name: CW2210064- phieu giao hang
#   - CW2210064- phieu giao hang.docx
#
# Base name: CW2211075- phieu giao hang
#   - CW2211075- phieu giao hang.docx
#
# Base name: CW2310062
#   - CW2310062.docx
#
# Base name: Cac loai Hop Dong
#   - Cac loai Hop Dong.docx
#
# Base name: Cam ket noi dung hang xuat_Eng_VNese V072014
#   - Cam ket noi dung hang xuat_Eng_VNese V072014.doc
#
# Base name: Cat 6 VISG Cable CQ
#   - Cat 6 VISG Cable CQ.docx
#
# Base name: Cert of Quality draft
#   - Cert of Quality draft.docx
#
# Base name: Chamberized CO   23011330_Vector Infotech
#   - Chamberized CO   23011330_Vector Infotech.docx
#
# Base name: Chamberized CO   23014413_Vector Infotech-cmt
#   - Chamberized CO   23014413_Vector Infotech-cmt.docx
#
# Base name: Chamberized CO   24002445_Vector Infotech
#   - Chamberized CO   24002445_Vector Infotech.docx
#
# Base name: Chamberized CO   24002672_Vector Infotech
#   - Chamberized CO   24002672_Vector Infotech.docx
#
# Base name: Chamberized CO 21048368_Vector Infotech Vietnam
#   - Chamberized CO 21048368_Vector Infotech Vietnam.docx
#
# Base name: Chamberized CO 21048705_Vector Infotech Vietnam
#   - Chamberized CO 21048705_Vector Infotech Vietnam.docx
#
# Base name: Cisco Systems Vietnam Limited
#   - Cisco Systems Vietnam Limited.doc
#   - Cisco Systems Vietnam Limited.docx
#
# Base name: Clarification Points
#   - Clarification Points.docx
#
# Base name: Commercial Contract - Belden Training
#   - Commercial Contract - Belden Training.docx
#
# Base name: Commercial Contract - Belden Training Draft
#   - Commercial Contract - Belden Training Draft.docx
#
# Base name: Commercial Contract - Dwisolar Draft
#   - Commercial Contract - Dwisolar Draft.docx
#
# Base name: Commercial Contract - Dwsolar
#   - Commercial Contract - Dwsolar.docx
#
# Base name: Commercial Contract - EIS - 14 July
#   - Commercial Contract - EIS - 14 July.docx
#
# Base name: Commercial Contract - EIS - 14 July ANNEX 1
#   - Commercial Contract - EIS - 14 July ANNEX 1.docx
#
# Base name: Commercial Contract - EIS - 14 July Customs Clearance Copy Aug 5 14
#   - Commercial Contract - EIS - 14 July Customs Clearance Copy Aug 5 14.docx
#
# Base name: Commercial Contract - Samlex-14 July
#   - Commercial Contract - Samlex-14 July.docx
#
# Base name: Commercial Contract - Samplex-25 july
#   - Commercial Contract - Samplex-25 july.docx
#
# Base name: Commercial Contract - Samplex-25 july  Revised
#   - Commercial Contract - Samplex-25 july  Revised.docx
#
# Base name: Complete Cert - Petronas
#   - Complete Cert - Petronas.docx
#
# Base name: Con dau VISG
#   - Con dau VISG.docx
#
# Base name: Con dau VIVN
#   - Con dau VIVN.docx
#
# Base name: Con dau&chu ki Hirschmann - CO
#   - Con dau&chu ki Hirschmann - CO.docx
#
# Base name: Con dau&chu ki Hirschmann - CO - Copy
#   - Con dau&chu ki Hirschmann - CO - Copy.docx
#
# Base name: Con dau&chu ki Hirschmann- CQQ
#   - Con dau&chu ki Hirschmann- CQQ.docx
#
# Base name: Confirmation Letter -Rittal-updated
#   - Confirmation Letter -Rittal-updated.docx
#
# Base name: Confirmation Letter for CQ_14_11
#   - Confirmation Letter for CQ_14_11.docx
#
# Base name: Confirmation Letter-FiberTek
#   - Confirmation Letter-FiberTek.docx
#
# Base name: Confirmation for the use of digital signature
#   - Confirmation for the use of digital signature.doc
#
# Base name: Confirmation letter ND
#   - Confirmation letter ND.docx
#
# Base name: Confirmation of CO to PetroSetco
#   - Confirmation of CO to PetroSetco.docx
#
# Base name: Confirmation of CO to PetroSetco draft
#   - Confirmation of CO to PetroSetco draft.docx
#
# Base name: Cong van _cmt
#   - Cong van _cmt.docx
#
# Base name: Cong van giai trinh hang Tai nhap
#   - Cong van giai trinh hang Tai nhap.doc
#
# Base name: Cong van giai trinh hang Tam Xuat_03.01.19
#   - Cong van giai trinh hang Tam Xuat_03.01.19.doc
#
# Base name: Cong van xac nhan SP Vector-Infotech
#   - Cong van xac nhan SP Vector-Infotech.doc
#
# Base name: Cong van yeu cau cuoc hop
#   - Cong van yeu cau cuoc hop.doc
#
# Base name: Cong van yeu cau thanh toan dung han
#   - Cong van yeu cau thanh toan dung han.doc
#
# Base name: Consortium Agreement VIVN - HQC_final
#   - Consortium Agreement VIVN - HQC_final.docx
#
# Base name: Contract 06.06.23 - Vector-Phuc Truong (Draft) (1)
#   - Contract 06.06.23 - Vector-Phuc Truong (Draft) (1).docx
#
# Base name: Contract 2002009-01-VECTOR-RECOTE
#   - Contract 2002009-01-VECTOR-RECOTE.docx
#
# Base name: Contract 2005026-01-VECTOR-YOKO
#   - Contract 2005026-01-VECTOR-YOKO.docx
#
# Base name: Contract 2005026-02 - YOKO - service R1
#   - Contract 2005026-02 - YOKO - service R1.docx
#
# Base name: Contract 2005026-02 - YOKO - service R2
#   - Contract 2005026-02 - YOKO - service R2.docx
#
# Base name: Contract 2104024-01-VECTOR-NLX Final
#   - Contract 2104024-01-VECTOR-NLX Final.docx
#
# Base name: Contract BD-OPS-2021-025A - Vector Infotech commented 290421
#   - Contract BD-OPS-2021-025A - Vector Infotech commented 290421.docx
#
# Base name: Contract draft_rev.01
#   - Contract draft_rev.01.doc
#
# Base name: Contract draft_rev.02_11.10.2017
#   - Contract draft_rev.02_11.10.2017.doc
#
# Base name: Contract-VIMAS- TVT UPs và Camera Draft
#   - Contract-VIMAS- TVT UPs và Camera Draft.doc
#
# Base name: Contract-VIMAS- TVT UPs và Camera Draft by Ngoc Dinh Jan 7 15
#   - Contract-VIMAS- TVT UPs và Camera Draft by Ngoc Dinh Jan 7 15.doc
#
# Base name: Contract-VIMAS-Meinberg UPs và Camera
#   - Contract-VIMAS-Meinberg UPs và Camera.doc
#
# Base name: Contract-VIMAS-Meinberg UPs và Camera Draft
#   - Contract-VIMAS-Meinberg UPs và Camera Draft.doc
#
# Base name: Contract_Vector_E_draft
#   - Contract_Vector_E_draft.docx
#
# Base name: Contract_Vector_V_draft
#   - Contract_Vector_V_draft.docx
#
# Base name: Cover
#   - Cover.docx
#
# Base name: Cover Sheet QC
#   - Cover Sheet QC.docx
#
# Base name: Cover and table of contents
#   - Cover and table of contents.docx
#
# Base name: Cover and table of contents Lavender
#   - Cover and table of contents Lavender.docx
#
# Base name: Cover page
#   - Cover page.docx
#
# Base name: Credit application - E2S
#   - Credit application - E2S.docx
#
# Base name: Ctr-129-VIT-CEN- Bien Dong Project-P8608 Ex & AAD-Final
#   - Ctr-129-VIT-CEN- Bien Dong Project-P8608 Ex & AAD-Final.doc
#
# Base name: CÔNG TY TNHH ĐIỆN CƠ TRẦN QUANG
#   - CÔNG TY TNHH ĐIỆN CƠ TRẦN QUANG.docx
#
# Base name: CÔNG VĂN GIẢI TRÌNH KHÔNG CÓ CFS
#   - CÔNG VĂN GIẢI TRÌNH KHÔNG CÓ CFS.docx
#
# Base name: CÔNG VĂN XIN GIA HẠN THỜI HẠN TÁI XUẤT - 2
#   - CÔNG VĂN XIN GIA HẠN THỜI HẠN TÁI XUẤT - 2.doc
#
# Base name: Công ty infortech 21_11
#   - Công ty infortech 21_11.docx
#
# Base name: Công van phat HĐ
#   - Công van phat HĐ.docx
#
# Base name: Công văn 190726
#   - Công văn 190726.doc
#
# Base name: Công văn 190726- revised
#   - Công văn 190726- revised.doc
#
# Base name: Công văn 190726- revised 01
#   - Công văn 190726- revised 01.doc
#
# Base name: Công văn giải trình
#   - Công văn giải trình.doc
#
# Base name: Công văn giải trình reviewed by F&G
#   - Công văn giải trình reviewed by F&G.doc
#
# Base name: Công văn gửi FPT Đề nghị trả tiền thừa
#   - Công văn gửi FPT Đề nghị trả tiền thừa.doc
#
# Base name: Công văn gửi FPT Đề nghị trả tiền thừa.doc
#   - Công văn gửi FPT Đề nghị trả tiền thừa.doc.docx
#
# Base name: Công văn nhắc nợ
#   - Công văn nhắc nợ.doc
#
# Base name: Công văn phúc đáp - Công ty infotech
#   - Công văn phúc đáp - Công ty infotech.docx
#
# Base name: Công văn thông báo thầu VEC -01
#   - Công văn thông báo thầu VEC -01.doc
#
# Base name: DANH MỤC THIẾT BỊ THU PHÁT SÓNG VÔ TUYẾN ĐIỆN
#   - DANH MỤC THIẾT BỊ THU PHÁT SÓNG VÔ TUYẾN ĐIỆN.doc
#
# Base name: DAP 2 SELV contract template
#   - DAP 2 SELV contract template.doc
#
# Base name: DATHANG-VT293 CP Tech Quote to be updated Mar 15 rev 1
#   - DATHANG-VT293 CP Tech Quote to be updated Mar 15 rev 1.docx
#
# Base name: DHG-ATA-CW-1-IN-PRO-004_ICSS_SAT Plan  Procedure_Rev C
#   - DHG-ATA-CW-1-IN-PRO-004_ICSS_SAT Plan  Procedure_Rev C.docx
#
# Base name: DHG-VIT-DD-0-CS-PRO-001_SAT_Rev0
#   - DHG-VIT-DD-0-CS-PRO-001_SAT_Rev0.doc
#
# Base name: DN 2310065 - Delivery notice
#   - DN 2310065 - Delivery notice.docx
#
# Base name: DN CT2310065'- Delivery notice
#   - DN CT2310065'- Delivery notice.docx
#
# Base name: DN SP1605001- YVN-VIT Nov 10 16
#   - DN SP1605001- YVN-VIT Nov 10 16.docx
#
# Base name: DN with detail SN
#   - DN with detail SN.docx
#
# Base name: DN1810046 - Final
#   - DN1810046 - Final.docx
#
# Base name: DN1811050 - clear stock NCSP
#   - DN1811050 - clear stock NCSP.docx
#
# Base name: DN181149 - For Intel
#   - DN181149 - For Intel.docx
#
# Base name: DN1812055-02 - BPS-405
#   - DN1812055-02 - BPS-405.docx
#
# Base name: DN1901001 - for S5T
#   - DN1901001 - for S5T.docx
#
# Base name: DN1903011- for MT
#   - DN1903011- for MT.docx
#
# Base name: DN1904026
#   - DN1904026.docx
#
# Base name: DN2203016- Danh Sach Hang
#   - DN2203016- Danh Sach Hang.docx
#
# Base name: DN2306037-Belden for Yokogawa
#   - DN2306037-Belden for Yokogawa.docx
#
# Base name: DRAF HD-611-2021-HQ-VIV-comment
#   - DRAF HD-611-2021-HQ-VIV-comment.docx
#
# Base name: Dai Hung Gas Gathering-CQQ (Draft)
#   - Dai Hung Gas Gathering-CQQ (Draft).docx
#
# Base name: Dai Hung Gas Gathering-System Warranty
#   - Dai Hung Gas Gathering-System Warranty.docx
#
# Base name: Dai Hung Gas Gathering-System Warranty 1
#   - Dai Hung Gas Gathering-System Warranty 1.docx
#
# Base name: Daily report_MAINTENANCE SERVICE FOR NDB  _24-12-2020
#   - Daily report_MAINTENANCE SERVICE FOR NDB  _24-12-2020.docx
#
# Base name: Daily report_MAINTENANCE SERVICE FOR NDB  _25-12-2020
#   - Daily report_MAINTENANCE SERVICE FOR NDB  _25-12-2020.docx
#
# Base name: Daily report_MAINTENANCE SERVICE FOR NDB  _26-12-2020
#   - Daily report_MAINTENANCE SERVICE FOR NDB  _26-12-2020.docx
#
# Base name: Daily report_MAINTENANCE SERVICE FOR NDB  _27-12-2020
#   - Daily report_MAINTENANCE SERVICE FOR NDB  _27-12-2020.docx
#
# Base name: Daily report_MAINTENANCE SERVICE FOR NDB  _28-12-2020
#   - Daily report_MAINTENANCE SERVICE FOR NDB  _28-12-2020.docx
#
# Base name: Danh muc Bieu mau PL5 - GSQL
#   - Danh muc Bieu mau PL5 - GSQL.docx
#
# Base name: Danh muc Bieu mau TXNK ngay 30.01.2015
#   - Danh muc Bieu mau TXNK ngay 30.01.2015.docx
#
# Base name: Danh muc Bieu mau kem Nghi dinh
#   - Danh muc Bieu mau kem Nghi dinh.docx
#
# Base name: Danh muc kem theo TT31
#   - Danh muc kem theo TT31.doc
#
# Base name: Danh muc kem theo TT32
#   - Danh muc kem theo TT32.doc
#
# Base name: Danh mục hàng hóa & serial no.
#   - Danh mục hàng hóa & serial no..docx
#
# Base name: Dau hop quy - in dan len thiet bi
#   - Dau hop quy - in dan len thiet bi.docx
#
# Base name: Dau hop quy - inl com info
#   - Dau hop quy - inl com info.docx
#
# Base name: Dau hop quy for print
#   - Dau hop quy for print.docx
#
# Base name: Detail CQ
#   - Detail CQ.docx
#
# Base name: Detail CQ Det-tronics
#   - Detail CQ Det-tronics.docx
#
# Base name: Detail CQ-ONEDRIVEBACKUP
#   - Detail CQ-ONEDRIVEBACKUP.docx
#
# Base name: Detail CQ_S1
#   - Detail CQ_S1.docx
#
# Base name: Detail CQ_S2
#   - Detail CQ_S2.docx
#
# Base name: Detail CQ_S3
#   - Detail CQ_S3.docx
#
# Base name: Detail PKL_Display
#   - Detail PKL_Display.docx
#
# Base name: Detail PKL_Gas Sensor Module
#   - Detail PKL_Gas Sensor Module.docx
#
# Base name: Detail PKL_Transmitter
#   - Detail PKL_Transmitter.docx
#
# Base name: Document transmittal
#   - Document transmittal.docx
#
# Base name: Domestic_ PO2406044-XX
#   - Domestic_ PO2406044-XX.docx
#
# Base name: Don huy
#   - Don huy.docx
#
# Base name: Draft - 241510 VECOTRINFOTECH-BEELOGISTICS contract
#   - Draft - 241510 VECOTRINFOTECH-BEELOGISTICS contract.doc
#
# Base name: Draft -STT Paga LOI Industronics Germany (VISG) revised
#   - Draft -STT Paga LOI Industronics Germany (VISG) revised.docx
#
# Base name: Draft CI and PL WIP 40 K 1st shipment
#   - Draft CI and PL WIP 40 K 1st shipment.docx
#
# Base name: Draft CI-PL
#   - Draft CI-PL.docx
#
# Base name: Draft CI-PL rev 1
#   - Draft CI-PL rev 1.docx
#
# Base name: Draft CI-PL rev 2
#   - Draft CI-PL rev 2.docx
#
# Base name: Draft CO
#   - Draft CO.docx
#
# Base name: Draft COC_PO1907042-01
#   - Draft COC_PO1907042-01.DOC
#
# Base name: Draft COC_PO2008046-01
#   - Draft COC_PO2008046-01.DOC
#
# Base name: Draft CONTRACT-Telecom System rev 20141021
#   - Draft CONTRACT-Telecom System rev 20141021.doc
#
# Base name: Draft CONTRACT-Telecom System revised by Vector (2)
#   - Draft CONTRACT-Telecom System revised by Vector (2).doc
#
# Base name: Draft COO manufacturer Autronica
#   - Draft COO manufacturer Autronica.doc
#
# Base name: Draft COO_PO1907042-01
#   - Draft COO_PO1907042-01.DOC
#
# Base name: Draft COO_PO2008046-01
#   - Draft COO_PO2008046-01.DOC
#
# Base name: Draft CoC
#   - Draft CoC.docx
#
# Base name: Draft Cong van
#   - Draft Cong van.docx
#
# Base name: Draft DOC Autronica BOM
#   - Draft DOC Autronica BOM.doc
#
# Base name: Draft DOC Autronica BOM-NGOCDINH
#   - Draft DOC Autronica BOM-NGOCDINH.doc
#
# Base name: Draft DOC Autronica BU-47
#   - Draft DOC Autronica BU-47.doc
#
# Base name: Draft PO 0006 Rev
#   - Draft PO 0006 Rev.doc
#
# Base name: Draft PO 0006_Cert comment by Vector on Feb 10
#   - Draft PO 0006_Cert comment by Vector on Feb 10.doc
#
# Base name: Draft RO#VIVN-RO-01
#   - Draft RO#VIVN-RO-01.doc
#
# Base name: Draft VISG Contract-July 2015 Foroozan
#   - Draft VISG Contract-July 2015 Foroozan.doc
#
# Base name: Draft_Loan_Agreement_v3
#   - Draft_Loan_Agreement_v3.docx
#
# Base name: Du thao Hop dong OTN
#   - Du thao Hop dong OTN.docx
#
# Base name: Dự thảo HD Sunbay Park ISD VN - VIVN - 11012020
#   - Dự thảo HD Sunbay Park ISD VN - VIVN - 11012020.docx
#
# Base name: DỰ THẢO HĐ-HSMT VT-0587-24-KT_(VECTOR)_VER0
#   - DỰ THẢO HĐ-HSMT VT-0587-24-KT_(VECTOR)_VER0.docx
#
# Base name: DỰ THẢO HĐ-HSMT VT-0587-24-KT_(VECTOR)_VER0_comment
#   - DỰ THẢO HĐ-HSMT VT-0587-24-KT_(VECTOR)_VER0_comment.docx
#
# Base name: Dự thảo BH
#   - Dự thảo BH.doc
#
# Base name: Dự thảo HD Sunbay Park ISD VN- Dec 14 2020 ND
#   - Dự thảo HD Sunbay Park ISD VN- Dec 14 2020 ND.docx
#
# Base name: Dự thảo HD Sunbay Park ISD VN- Dec 21 2020 ND
#   - Dự thảo HD Sunbay Park ISD VN- Dec 21 2020 ND.docx
#
# Base name: Dự thảo HD Sunbay Park Vector VN- Dec 14 2020 ND
#   - Dự thảo HD Sunbay Park Vector VN- Dec 14 2020 ND .docx
#
# Base name: Dự thảo HD Sunbay Park Vector VN-rev 3 - Nov  24 2020 Rev 4 by Mr Nguyen
#   - Dự thảo HD Sunbay Park Vector VN-rev 3 - Nov  24 2020 Rev 4 by Mr Nguyen.docx
#
# Base name: Equipment Borrow Contract - Dwisolar
#   - Equipment Borrow Contract - Dwisolar.docx
#
# Base name: Equipment Borrow Contract-Autronica Demo
#   - Equipment Borrow Contract-Autronica Demo.docx
#
# Base name: Equipment Borrow Contract-Engtek Demo-Sin- OK
#   - Equipment Borrow Contract-Engtek Demo-Sin- OK.docx
#
# Base name: Equipment Inspection
#   - Equipment Inspection.doc
#
# Base name: Equipment Inspection  JVPC
#   - Equipment Inspection  JVPC.docx
#
# Base name: Equipment Inspection  JVPC Formattedd
#   - Equipment Inspection  JVPC Formattedd.docx
#
# Base name: Equipment Return Contract-Det-Sing-final
#   - Equipment Return Contract-Det-Sing-final.docx
#
# Base name: Equipment list (1)
# ...
#   - Thong bao hang _en_4013002895.docx
#
# Base name: Thong bao hang _en_4830492321
#   - Thong bao hang _en_4830492321.docx
#
# Base name: Thong bao hang _en_6342973265
#   - Thong bao hang _en_6342973265.docx
#
# Base name: Thong tin lay hang lai
#   - Thong tin lay hang lai.docx
#
# Base name: Thong tu 38
#   - Thong tu 38.doc
#
# Base name: Thu moi chao gia_01_template
#   - Thu moi chao gia_01_template.docx
#
# Base name: Thu moi chao gia_07
#   - Thu moi chao gia_07.docx
#
# Base name: Thông báo hàng _¿n_1549396030
#   - Thông báo hàng _¿n_1549396030.docx
#
# Base name: Thông tin hàng
#   - Thông tin hàng.docx
#
# Base name: Thông tin hàng PO2106035-01- for PandC
#   - Thông tin hàng PO2106035-01- for PandC.docx
#
# Base name: Thông tin hàng- PO2104020-01-  Winmate for Yokogawa
#   - Thông tin hàng- PO2104020-01-  Winmate for Yokogawa.docx
#
# Base name: Thỏa thuận hợp đồng - song ngu VSP - final
#   - Thỏa thuận hợp đồng - song ngu VSP - final.doc
#
# Base name: Tu danh gia kq
#   - Tu danh gia kq.docx
#
# Base name: TĐH KCM24_017- CMVN-VECTOR commented
#   - TĐH KCM24_017- CMVN-VECTOR commented.docx
#
# Base name: UQ Intel - Vivn ( to be signed off by Intel)
#   - UQ Intel - Vivn ( to be signed off by Intel).docx
#
# Base name: Untitled attachment 00283
#   - Untitled attachment 00283.docx
#
# Base name: VECTOR  AES (draft) by Yen
#   - VECTOR  AES (draft) by Yen.doc
#
# Base name: VECTOR 20424122 RSK - comment
#   - VECTOR 20424122 RSK - comment.DOC
#
# Base name: VECTOR 20425326 RSK - COO
#   - VECTOR 20425326 RSK - COO.DOC
#
# Base name: VECTOR 20427860 RSK - COO
#   - VECTOR 20427860 RSK - COO.DOC
#
# Base name: VECTOR 20429313 CSD-comment
#   - VECTOR 20429313 CSD-comment.DOC
#
# Base name: VECTOR 20430235 CSD-comment
#   - VECTOR 20430235 CSD-comment.DOC
#
# Base name: VECTOR 21427664 21429691 CSD
#   - VECTOR 21427664 21429691 CSD.doc
#
# Base name: VECTOR 21427664 21429691 CSD-format
#   - VECTOR 21427664 21429691 CSD-format.doc
#
# Base name: VECTOR 21428060 RSK
#   - VECTOR 21428060 RSK.doc
#
# Base name: VECTOR 21429691 + 21429792 RSK-comment
#   - VECTOR 21429691 + 21429792 RSK-comment.doc
#
# Base name: VECTOR 24434963 SRO - amended draft
#   - VECTOR 24434963 SRO - amended draft.doc
#
# Base name: VECTOR INFO TECH 20424122 RSK - comment
#   - VECTOR INFO TECH 20424122 RSK - comment.DOC
#
# Base name: VECTOR INFO TECH 20424122 RSK - comment-FileSrv-VIVN
#   - VECTOR INFO TECH 20424122 RSK - comment-FileSrv-VIVN.DOC
#
# Base name: VECTOR INFO TECH 20425326 RSK - CQQ
#   - VECTOR INFO TECH 20425326 RSK - CQQ.DOC
#
# Base name: VECTOR INFO TECH 20425365 RSK - comment
#   - VECTOR INFO TECH 20425365 RSK - comment.DOC
#
# Base name: VECTOR INFO TECH 20425371 RSK comment
#   - VECTOR INFO TECH 20425371 RSK comment.DOC
#
# Base name: VECTOR INFO TECH 20427860 RSK - CQQ
#   - VECTOR INFO TECH 20427860 RSK - CQQ.DOC
#
# Base name: VECTOR INFO TECH 21427664 + 21429691 CSD
#   - VECTOR INFO TECH 21427664 + 21429691 CSD.doc
#
# Base name: VECTOR INFO TECH 21427664 + 21429691 CSD -comment
#   - VECTOR INFO TECH 21427664 + 21429691 CSD -comment.doc
#
# Base name: VECTOR INFO TECH 21428060 CSD - HStech
#   - VECTOR INFO TECH 21428060 CSD - HStech.doc
#
# Base name: VECTOR INFO TECH 21428060 RSK
#   - VECTOR INFO TECH 21428060 RSK.doc
#
# Base name: VECTOR INFO TECH 21429691 + 21429792 RSK-comment
#   - VECTOR INFO TECH 21429691 + 21429792 RSK-comment.doc
#
# Base name: VECTOR INFO TECH 21438174 SRO-comment
#   - VECTOR INFO TECH 21438174 SRO-comment.doc
#
# Base name: VECTOR INFO TECH 24440338 RSK - rvs
#   - VECTOR INFO TECH 24440338 RSK - rvs.doc
#
# Base name: VECTOR INFOTECH 23447693 CSD
#   - VECTOR INFOTECH 23447693 CSD.doc
#
# Base name: VECTOR INFOTECH TNT Contract 2015 Revised
#   - VECTOR INFOTECH TNT Contract 2015 Revised.doc
#
# Base name: VECTOR INFOTECH_HĐ_SOPHOS XGS136_28.06.2022
#   - VECTOR INFOTECH_HĐ_SOPHOS XGS136_28.06.2022.doc
#
# Base name: VECTOR-CV Phat hang hoa
#   - VECTOR-CV Phat hang hoa.docx
#
# Base name: VEDTOR INFO TECH 20422758 RSK - comment
#   - VEDTOR INFO TECH 20422758 RSK - comment.DOC
#
# Base name: VENDOR DATA MANUFACTURER LIST
#   - VENDOR DATA MANUFACTURER LIST.docx
#
# Base name: VIETTEL-SAMPLE02
#   - VIETTEL-SAMPLE02.docx
#
# Base name: VIETTEL-SAMPLE03
#   - VIETTEL-SAMPLE03.docx
#
# Base name: VISG Contract Dec 2014
#   - VISG Contract Dec 2014.doc
#
# Base name: VISG Contract Jan to Sep 2014
#   - VISG Contract Jan to Sep 2014.doc
#
# Base name: VISG Contract Nov 2014
#   - VISG Contract Nov 2014.doc
#
# Base name: VISG Contract Oct 2014
#   - VISG Contract Oct 2014.doc
#
# Base name: VISG Contract- HD 238 USD
#   - VISG Contract- HD 238 USD.doc
#
# Base name: VISG Contract-01-2016
#   - VISG Contract-01-2016.doc
#
# Base name: VISG Contract-02-2016
#   - VISG Contract-02-2016.doc
#
# Base name: VISG Contract-03-2016
#   - VISG Contract-03-2016.doc
#
# Base name: VISG Contract-04 to 10-2016
#   - VISG Contract-04 to 10-2016.doc
#
# Base name: VISG Contract-Arp 2015
#   - VISG Contract-Arp 2015.doc
#
# Base name: VISG Contract-Aug 2015
#   - VISG Contract-Aug 2015.doc
#
# Base name: VISG Contract-Feb 2015
#   - VISG Contract-Feb 2015.doc
#
# Base name: VISG Contract-HD 237
#   - VISG Contract-HD 237.DOC
#
# Base name: VISG Contract-INV 2 - Copy
#   - VISG Contract-INV 2 - Copy.DOC
#
# Base name: VISG Contract-INV 3
#   - VISG Contract-INV 3.DOC
#
# Base name: VISG Contract-Jan 2015
#   - VISG Contract-Jan 2015.doc
#
# Base name: VISG Contract-July 2015
#   - VISG Contract-July 2015.doc
#
# Base name: VISG Contract-June 2015
#   - VISG Contract-June 2015.doc
#
# Base name: VISG Contract-Mar 2015
#   - VISG Contract-Mar 2015.doc
#
# Base name: VISG Contract-May 2015
#   - VISG Contract-May 2015.doc
#
# Base name: VISG Contract-Nov-2015
#   - VISG Contract-Nov-2015.doc
#
# Base name: VISG Contract-Nov-2015 - Copy
#   - VISG Contract-Nov-2015 - Copy.doc
#
# Base name: VISG Contract-Oct-2015
#   - VISG Contract-Oct-2015.doc
#
# Base name: VISG Contract-Sep 2015
#   - VISG Contract-Sep 2015.doc
#
# Base name: VISg contract 2013 - Service over sea
#   - VISg contract 2013 - Service over sea.doc
#
# Base name: VIV-PVEP-L-0001 - Delivery notice
#   - VIV-PVEP-L-0001 - Delivery notice.docx
#
# Base name: VIVN Reference List - Telecom
#   - VIVN Reference List - Telecom.docx
#
# Base name: VIVN- VISG -Cisco for Dai Hung VSP Contract for Bank Payment
#   - VIVN- VISG -Cisco for Dai Hung VSP Contract for Bank Payment.doc
#
# Base name: VIVN- VISG -Cisco for Dai Hung VSP Contract for Bank Payment No Signature
#   - VIVN- VISG -Cisco for Dai Hung VSP Contract for Bank Payment No Signature.doc
#
# Base name: VIVN-CV-131020 - English
#   - VIVN-CV-131020 - English.doc
#
# Base name: VIVN-CV-200325- doi PN cho phu kien ATS
#   - VIVN-CV-200325- doi PN cho phu kien ATS.doc
#
# Base name: VIVN-CV-200407 - cong van xin mien phat
#   - VIVN-CV-200407 - cong van xin mien phat.doc
#
# Base name: VIVN-CV-201120 - CV Giải trình về việc phạt châm giao hàng
#   - VIVN-CV-201120 - CV Giải trình về việc phạt châm giao hàng.doc
#
# Base name: VIVN-CV-210415-HSTECH
#   - VIVN-CV-210415-HSTECH.doc
#
# Base name: VIVN-CV-210415-HSTECH 1
#   - VIVN-CV-210415-HSTECH 1.doc
#
# Base name: VIVN-CV-291020 - Tieng Viet
#   - VIVN-CV-291020 - Tieng Viet.doc
#
# Base name: VIVN-CV-291020 - Tieng Viet Ngoc checked
#   - VIVN-CV-291020 - Tieng Viet Ngoc checked.doc
#
# Base name: VIVN-CV-NACIS -  03082022
#   - VIVN-CV-NACIS -  03082022.doc
#
# Base name: VIVN-CV-NACIS - 03.06.2022
#   - VIVN-CV-NACIS - 03.06.2022.doc
#
# Base name: VIVN-CV-NACIS - 03.06.2022-FileSrv-VIVN
#   - VIVN-CV-NACIS - 03.06.2022-FileSrv-VIVN.doc
#
# Base name: VIVN-CV-NACIS - 06.06.2022
#   - VIVN-CV-NACIS - 06.06.2022.doc
#
# Base name: VIVN-CV-NACIS - 060922
#   - VIVN-CV-NACIS - 060922.doc
#
# Base name: VIVN-CV-NACIS - 19042023
#   - VIVN-CV-NACIS - 19042023.doc
#
# Base name: VIVN-CV-NACIS - 28.04.2022 - sample
#   - VIVN-CV-NACIS - 28.04.2022 - sample.doc
#
# Base name: VIVN-CV-NACIS - CV VIT 04062021 native
#   - VIVN-CV-NACIS - CV VIT 04062021 native.docx
#
# Base name: VIVN-CV-NACIS - cong van yeu cau ho tro kiem tra sp mmds -11.05.2021
#   - VIVN-CV-NACIS - cong van yeu cau ho tro kiem tra sp mmds -11.05.2021.doc
#
# Base name: VIVN-CV-NACIS - cong van yeu cau ho tro kiem tra sp mmds -17.01.2022
#   - VIVN-CV-NACIS - cong van yeu cau ho tro kiem tra sp mmds -17.01.2022.doc
#
# Base name: VIVN-Cisco  via Ingram Micro draft Contract
#   - VIVN-Cisco  via Ingram Micro draft Contract.doc
#
# Base name: VIVN_CV_0210_REMIND PAYMENT Letter-TLJOC
#   - VIVN_CV_0210_REMIND PAYMENT Letter-TLJOC.docx
#
# Base name: VIVN_CV_0304_Letter
#   - VIVN_CV_0304_Letter.docx
#
# Base name: VIVN_CV_0304_gia han thoi gian giao hang
#   - VIVN_CV_0304_gia han thoi gian giao hang.docx
#
# Base name: VIVN_CV_221512.VECTOR-3S
#   - VIVN_CV_221512.VECTOR-3S.docx
#
# Base name: VIVN_CV_221912.VECTOR-3S
#   - VIVN_CV_221912.VECTOR-3S.docx
#
# Base name: VIVN_CV_2806_Letter-TLJOC
#   - VIVN_CV_2806_Letter-TLJOC.docx
#
# Base name: VIVN_ISO_DanhMucHoSo_181011
#   - VIVN_ISO_DanhMucHoSo_181011.doc
#
# Base name: VSP-BBNT HD
#   - VSP-BBNT HD.doc
#
# Base name: VSP-BBNT HD 003019BMĐH VECTOR
#   - VSP-BBNT HD 003019BMĐH VECTOR.doc
#
# Base name: VSP-BBNT HD 003019BMĐH VECTOR (1)
#   - VSP-BBNT HD 003019BMĐH VECTOR (1).doc
#
# Base name: VSP-BBNT HD 003019BMĐH VECTOR (4)
#   - VSP-BBNT HD 003019BMĐH VECTOR (4).doc
#
# Base name: VSP-BBNT HD 0732.19.T-N5.CNTT- VECTOR
#   - VSP-BBNT HD 0732.19.T-N5.CNTT- VECTOR.doc
#
# Base name: VSP-BBNT HD 368-2-19-CNTT-VECTOR INFOTECH VN
#   - VSP-BBNT HD 368-2-19-CNTT-VECTOR INFOTECH VN.doc
#
# Base name: VSP-BBNT HD 368-2-19-CNTT-VECTOR INFOTECH VN-rev1
#   - VSP-BBNT HD 368-2-19-CNTT-VECTOR INFOTECH VN-rev1.doc
#
# Base name: VSP-BBNT HD 368-2-19-CNTT-VECTOR INFOTECH VN-rev2
#   - VSP-BBNT HD 368-2-19-CNTT-VECTOR INFOTECH VN-rev2.doc
#
# Base name: VSP-BBNT HD 368-2-19-CNTT-VECTOR INFOTECH VN-rev3
#   - VSP-BBNT HD 368-2-19-CNTT-VECTOR INFOTECH VN-rev3.doc
#
# Base name: VT293 - Junction Box - Quotation WEIDMULLER - CPTECH - 08 Oct 15 (2)
#   - VT293 - Junction Box - Quotation WEIDMULLER - CPTECH - 08 Oct 15 (2).doc
#
# Base name: VXM - AUtronica- Chi tiết hàng hoá
#   - VXM - AUtronica- Chi tiết hàng hoá.docx
#
# Base name: Vector - CO
#   - Vector - CO.docx
#
# Base name: Vector - COO
#   - Vector - COO.docx
#
# Base name: Vector - CQ
#   - Vector - CQ.docx
#
# Base name: Vector - CQ- Rv3
#   - Vector - CQ- Rv3.docx
#
# Base name: Vector - CQQ
#   - Vector - CQQ.docx
#
# Base name: Vector InfoTech Vietnam - F58_Vendor Registration Form_Rev1 (Bartec SG)
#   - Vector InfoTech Vietnam - F58_Vendor Registration Form_Rev1 (Bartec SG).docx
#
# Base name: Vector Infotech Private Limited-CQQ - Copy
#   - Vector Infotech Private Limited-CQQ - Copy.docx
#
# Base name: Vector Infotech Private Limited-Warranty
#   - Vector Infotech Private Limited-Warranty.docx
#
# Base name: Vector Infotech Vietnam  Invitation Letter 1015 Revised
#   - Vector Infotech Vietnam  Invitation Letter 1015 Revised.doc
#
# Base name: VectorInfotech-Cisco  via Ingram Micro Draft contract rev by VIVN
#   - VectorInfotech-Cisco  via Ingram Micro Draft contract rev by VIVN.doc
#
# Base name: Vendor registration form_PCOSB _
#   - Vendor registration form_PCOSB _.doc
#
# Base name: WHP-DH01-I-F-6513-C06-001V_A0_Packing Proposal
#   - WHP-DH01-I-F-6513-C06-001V_A0_Packing Proposal.docx
#
# Base name: WHP-DH01-I-F-6513-C06-001V_A0_Packing Proposal cmt
#   - WHP-DH01-I-F-6513-C06-001V_A0_Packing Proposal cmt.docx
#
# Base name: Warranty Cert - BD-OPS-2014-099A - Vector Infotech
#   - Warranty Cert - BD-OPS-2014-099A - Vector Infotech.docx
#
# Base name: YCBH hang hoa
#   - YCBH hang hoa.doc
#
# Base name: Yeu cau bao hiem Norway - VN
#   - Yeu cau bao hiem Norway - VN.doc
#
# Base name: Yeu cau bao hiem US - VN
#   - Yeu cau bao hiem US - VN.doc
#
# Base name: Yeu cau bao hiem USA - VN
#   - Yeu cau bao hiem USA - VN.doc
#
# Base name: Yeu cau bao hiem USA- VN
#   - Yeu cau bao hiem USA- VN.doc
#
# Base name: Yeu cau bao hiem VN - Bangladesh
#   - Yeu cau bao hiem VN - Bangladesh.doc
#
# Base name: Yeu cau bao hiem VN - UK
#   - Yeu cau bao hiem VN - UK.doc
#
# Base name: Yeu cau bao hiem noi dia HCM-QN
#   - Yeu cau bao hiem noi dia HCM-QN.doc
#
# Base name: Yêu cầu bảo hiểm HCM-TB
#   - Yêu cầu bảo hiểm HCM-TB.doc
#
# Base name: Yêu cầu bảo hiểm Norway - VN
#   - Yêu cầu bảo hiểm Norway - VN.doc
#
# Base name: Yêu cầu bảo hiểm TP HCM - Ha Noi
#   - Yêu cầu bảo hiểm TP HCM - Ha Noi.doc
#
# Base name: Yêu cầu bảo hiểm TP HCM - THAI BINH
#   - Yêu cầu bảo hiểm TP HCM - THAI BINH.doc
#
# Base name: Yêu cầu bảo hiểm TPHCM-THAI BINH
#   - Yêu cầu bảo hiểm TPHCM-THAI BINH.doc
#
# Base name: Yêu cầu bảo hiểm UK - VN
#   - Yêu cầu bảo hiểm UK - VN.doc
#
# Base name: [VIVN-BDPOC] - PO - 2019
#   - [VIVN-BDPOC] - PO - 2019.DOCX
#
# Base name: _TT75.2015.TT.BGTVTvaQuychuan
#   - _TT75.2015.TT.BGTVTvaQuychuan.doc
#
# Base name: bien ban kiem hang
#   - bien ban kiem hang.docx
#
# Base name: bien-ban-lam-viec-voi-khach-hang
#   - bien-ban-lam-viec-voi-khach-hang.doc
#
# Base name: cong van tam nhap
#   - cong van tam nhap.docx
#
# Base name: cong van tái xuất
#   - cong van tái xuất.docx
#
# Base name: customs declaration Hirschmann Demo 1
#   - customs declaration Hirschmann Demo 1.docx
#
# Base name: draft HĐ CT2004023_SI_YT. Vector - CI Tech
#   - draft HĐ CT2004023_SI_YT. Vector - CI Tech.doc
#
# Base name: draft bien ban tra hang
#   - draft bien ban tra hang.docx
#
# Base name: draft bien ban tra hang REV1
#   - draft bien ban tra hang REV1.docx
#
# Base name: draft công văn
#   - draft công văn.doc
#
# Base name: du thao HD_F-G-13-14-WIP-40000_infotech
#   - du thao HD_F-G-13-14-WIP-40000_infotech.doc
#
# Base name: du thao HD_F-G-13-14-WIP-40000_infotech Jan 20
#   - du thao HD_F-G-13-14-WIP-40000_infotech Jan 20.doc
#
# Base name: fibertek
#   - fibertek.docx
#
# Base name: hợp đồng Vector V1506
#   - hợp đồng Vector V1506.docx
#
# Base name: inv06 - service report
#   - inv06 - service report.docx
#
# Base name: inv06 - visg contract
#   - inv06 - visg contract.DOC
#
# Base name: inv21 - visg contract
#   - inv21 - visg contract.DOC
#
# Base name: inv24 - visg contract
#   - inv24 - visg contract.DOC
#
# Base name: inv25 - visg contract
#   - inv25 - visg contract.DOC
#
# Base name: inv26 - service report
#   - inv26 - service report.docx
#
# Base name: inv26 - visg contract
#   - inv26 - visg contract.DOC
#
# Base name: inv28 - service report
#   - inv28 - service report.docx
#
# Base name: inv28 - visg contract
#   - inv28 - visg contract.DOC
#
# Base name: inv29 - service report
#   - inv29 - service report.docx
#
# Base name: inv29 - visg contract
#   - inv29 - visg contract.DOC
#
# Base name: inv30 - service report
#   - inv30 - service report.docx
#
# Base name: inv30 - visg contract
#   - inv30 - visg contract.DOC
#
# Base name: inv37 - service report
#   - inv37 - service report.docx
#
# Base name: inv37 - visg contract
#   - inv37 - visg contract.DOC
#
# Base name: inv38 - service report
#   - inv38 - service report.docx
#
# Base name: inv38 - visg contract
#   - inv38 - visg contract.DOC
#
# Base name: inv39 - service report
#   - inv39 - service report.docx
#
# Base name: inv39 - visg contract
#   - inv39 - visg contract.DOC
#
# Base name: inv41 - service report
#   - inv41 - service report.docx
#
# Base name: inv41 - visg contract
#   - inv41 - visg contract.DOC
#
# Base name: letter from Samlex
#   - letter from Samlex.docx
#
# Base name: letter from Samlex rev 1
#   - letter from Samlex rev 1.docx
#
# Base name: mau dau hop quy
#   - mau dau hop quy.docx
#
# Base name: mau don de nghi huy tk
#   - mau don de nghi huy tk.doc
#
# Base name: mau-so-02-bkhd-gsql
#   - mau-so-02-bkhd-gsql.docx
#
# Base name: mau-so-02-bkhd-gsql (1)
#   - mau-so-02-bkhd-gsql (1).docx
#
# Base name: mau03_kbs_gsql
#   - mau03_kbs_gsql.docx
#
# Base name: note draft 2 (quan)
#   - note draft 2 (quan).docx
#
# Base name: phuluc II - TT 30-2011
#   - phuluc II - TT 30-2011.doc
#
# Base name: phuluc II - TT 30-2011 - dang ky hop quy
#   - phuluc II - TT 30-2011 - dang ky hop quy.doc
#
# Base name: purchase and sale Contract0805
#   - purchase and sale Contract0805.doc
#
# Base name: quyet toan dich vu
#   - quyet toan dich vu.docx
#
# Base name: revised_PO2308049-01 - Meinberg for OITC-detail discount - Copy
#   - revised_PO2308049-01 - Meinberg for OITC-detail discount - Copy.docx
#
# Base name: ten hang dwisolar
#   - ten hang dwisolar.docx
#
# Base name: thong-tu-15-2018-tt-btttt-ve-chung-nhan-hop-quy-voi-hang-hoa-chuyen-nganh-cntt
#   - thong-tu-15-2018-tt-btttt-ve-chung-nhan-hop-quy-voi-hang-hoa-chuyen-nganh-cntt.doc
#
# Base name: warehouse receiving note
#   - warehouse receiving note.docx
#
# Base name: x52af_cgb datasheet Datasheet VN (2)
#   - x52af_cgb datasheet Datasheet VN (2).docx

# %% [markdown]
# ### Split big DOC folder to smaller folders

# %%
import os
import shutil

# Source folder containing the PDFs
source_folder = r"D:\fd_doc_Prop_1885_split3"

# Target folders to copy the files
target_folder_1 = r"D:\fd_doc_Prop_1885_split31"
target_folder_2 = r"D:\fd_doc_Prop_1885_split32"
target_folder_3 = r"D:\fd_doc_Prop_1885_split33"

# Create target folders if they don't exist
os.makedirs(target_folder_1, exist_ok=True)
os.makedirs(target_folder_2, exist_ok=True)
os.makedirs(target_folder_3, exist_ok=True)

# Get list of all PDF files in the source folder
pdf_files = [file for file in os.listdir(source_folder) if file.lower().endswith(('.doc', '.docx'))]

# Sort the files to ensure consistent distribution
pdf_files.sort()

# Total number of files
total_files = len(pdf_files)

# Number of folders
num_folders = 3

# Calculate the base number of files per folder and the remainder
files_per_folder = total_files // num_folders  # Integer division
remainder_files = total_files % num_folders    # Modulo operation

# Initialize folder distributions
folder_distribution = [files_per_folder] * num_folders

# Distribute the remainder files to the first few folders
for i in range(remainder_files):
    folder_distribution[i] += 1

# Copy files to target folders
current_index = 0
target_folders = [target_folder_1, target_folder_2, target_folder_3]

for folder_index, file_count in enumerate(folder_distribution):
    target_folder = target_folders[folder_index]
    for _ in range(file_count):
        source_file = os.path.join(source_folder, pdf_files[current_index])
        destination_file = os.path.join(target_folder, pdf_files[current_index])
        shutil.copy(source_file, destination_file)
        current_index += 1

# Verify and print the number of files copied to each folder
files_copied_1 = len(os.listdir(target_folder_1))
files_copied_2 = len(os.listdir(target_folder_2))
files_copied_3 = len(os.listdir(target_folder_3))

total_copied = files_copied_1 + files_copied_2 + files_copied_3

print(f"Files have been successfully copied into three folders with distribution:")
print(f"Folder 1: {files_copied_1} files")
print(f"Folder 2: {files_copied_2} files")
print(f"Folder 3: {files_copied_3} files")
print(f"Total files copied: {total_copied}")

# Check if the total copied files equal the total files in source
if total_copied == total_files:
    print("All files have been successfully copied.")
else:
    print("There was an error in copying files.")
# Out:
# Files have been successfully copied into three folders with distribution:
# Folder 1: 210 files
# Folder 2: 210 files
# Folder 3: 210 files
# Total files copied: 630
# All files have been successfully copied.

# %% [markdown]
# ### Split big PDF folder to smaller folders

# %%
import os
import shutil

# Source folder containing the PDFs
source_folder = r"F:\Proposal_merge_20352"

# Number of folders to split into
num_folders = 8

# Generate target folder paths dynamically
target_folders = [os.path.join(source_folder + f"_split{i+1}") for i in range(num_folders)]

# Create target folders if they don't exist
for folder in target_folders:
    os.makedirs(folder, exist_ok=True)

# Get list of all PDF files in the source folder
pdf_files = [file for file in os.listdir(source_folder) if file.lower().endswith('.pdf')]

# Sort the files to ensure consistent distribution
pdf_files.sort()

# Total number of files
total_files = len(pdf_files)

# Calculate the base number of files per folder and the remainder
files_per_folder = total_files // num_folders  # Integer division
remainder_files = total_files % num_folders    # Modulo operation

# Initialize folder distributions
folder_distribution = [files_per_folder] * num_folders

# Distribute the remainder files to the first few folders
for i in range(remainder_files):
    folder_distribution[i] += 1

# Copy files to target folders
current_index = 0

for folder_index, file_count in enumerate(folder_distribution):
    target_folder = target_folders[folder_index]
    for _ in range(file_count):
        source_file = os.path.join(source_folder, pdf_files[current_index])
        destination_file = os.path.join(target_folder, pdf_files[current_index])
        shutil.copy(source_file, destination_file)
        current_index += 1

# Verify and print the number of files copied to each folder
files_copied = []
for folder in target_folders:
    files_copied.append(len([file for file in os.listdir(folder) if file.lower().endswith('.pdf')]))

total_copied = sum(files_copied)

print(f"Files have been successfully copied into {num_folders} folders with distribution:")
for i, count in enumerate(files_copied, 1):
    print(f"Folder {i}: {count} files")
print(f"Total files copied: {total_copied}")

# Check if the total copied files equal the total files in source
if total_copied == total_files:
    print("All files have been successfully copied.")
else:
    print("There was an error in copying files.")
# Out:
# Files have been successfully copied into 8 folders with distribution:
# Folder 1: 2544 files
# Folder 2: 2544 files
# Folder 3: 2544 files
# Folder 4: 2544 files
# Folder 5: 2544 files
# Folder 6: 2544 files
# Folder 7: 2544 files
# Folder 8: 2544 files
# Total files copied: 20352
# All files have been successfully copied.

# %% [markdown]
# ### Count total of splitted files to see sum is correct

# %%
import os
from pathlib import Path

def count_files_in_folder(folder_path):
    """
    Count all files (not directories) in a folder and its subfolders.
    
    Args:
        folder_path (str or Path): Path to the folder
        
    Returns:
        int: Number of files found
    """
    folder = Path(folder_path)
    if not folder.exists():
        print(f"Warning: Folder not found: {folder}")
        return 0
        
    return sum(1 for _ in folder.rglob('*') if _.is_file())

def count_files_in_split_folders(base_folder, base_name, start_num=1):
    """
    Count files in sequentially numbered folders.
    
    Args:
        base_folder (str): Base directory containing the split folders
        base_name (str): Base name of the folders (e.g., "Proposal_merge_20352_split")
        start_num (int): Starting number for the sequence
        
    Returns:
        dict: Dictionary with folder numbers as keys and file counts as values
        int: Total number of files across all folders
    """
    counts = {}
    total_files = 0
    folder_number = start_num
    
    while True:
        folder_path = os.path.join(base_folder, f"{base_name}{folder_number}")
        if not os.path.exists(folder_path):
            break
            
        file_count = count_files_in_folder(folder_path)
        counts[folder_number] = file_count
        total_files += file_count
        folder_number += 1
    
    return counts, total_files

if __name__ == "__main__":
    # Set your base folder and naming pattern
    base_folder = r"F:"  # Adjust this to your drive/path
    base_name = "Proposal_merge_20352_split"
    
    print("Counting files in folders...\n")
    counts, total = count_files_in_split_folders(base_folder, base_name)
    
    if counts:
        # Print individual folder counts
        print("Files per folder:")
        print("-" * 40)
        for folder_num, count in counts.items():
            print(f"Split {folder_num}: {count:,} files")
            
        # Print total
        print("\nSummary:")
        print("-" * 40)
        print(f"Total folders found: {len(counts)}")
        print(f"Total files across all folders: {total:,}")
    else:
        print("No matching folders found!")
# Out:
# Counting files in folders...
#
# Files per folder:
# ----------------------------------------
# Split 1: 2,541 files
# Split 2: 2,542 files
# Split 3: 2,543 files
# Split 4: 2,542 files
# Split 5: 2,543 files
# Split 6: 2,543 files
# Split 7: 2,542 files
# Split 8: 2,539 files
#
# Summary:
# ----------------------------------------
# Total folders found: 8
# Total files across all folders: 20,335

# %% [markdown]
# ### Check missing file in splitted folder

# %%
import os
from pathlib import Path
import hashlib

def get_files_info(folder_path):
    """
    Get information about all files in a folder and its subfolders.
    
    Args:
        folder_path (str or Path): Path to the folder
        
    Returns:
        dict: Dictionary with filenames as keys and tuples of (size, path) as values
    """
    folder = Path(folder_path)
    files_info = {}
    
    for file_path in folder.rglob('*'):
        if file_path.is_file():
            # Store both file size and full path
            files_info[file_path.name] = (file_path.stat().st_size, str(file_path))
            
    return files_info

def compare_folders(original_folder, split_base_folder, split_base_name):
    """
    Compare files between original folder and split folders.
    
    Args:
        original_folder (str): Path to the original folder
        split_base_folder (str): Base directory containing the split folders
        split_base_name (str): Base name of the split folders
    """
    print("Gathering files information...")
    
    # Get files from original folder
    original_files = get_files_info(original_folder)
    print(f"Original folder contains {len(original_files):,} files")
    
    # Get files from all split folders
    split_files = {}
    folder_number = 1
    
    while True:
        folder_path = os.path.join(split_base_folder, f"{split_base_name}{folder_number}")
        if not os.path.exists(folder_path):
            break
            
        folder_files = get_files_info(folder_path)
        split_files.update(folder_files)
        folder_number += 1
    
    print(f"Split folders contain {len(split_files):,} files")
    
    # Find files in original but not in splits
    missing_in_splits = set(original_files.keys()) - set(split_files.keys())
    
    # Find files in splits but not in original
    extra_in_splits = set(split_files.keys()) - set(original_files.keys())
    
    # Print results
    print("\nComparison Results:")
    print("-" * 50)
    
    if missing_in_splits:
        print("\nFiles present in original but missing from splits:")
        for filename in missing_in_splits:
            size, path = original_files[filename]
            print(f"- {filename}")
            print(f"  Location: {path}")
            print(f"  Size: {size:,} bytes")
    
    if extra_in_splits:
        print("\nFiles present in splits but missing from original:")
        for filename in extra_in_splits:
            size, path = split_files[filename]
            print(f"- {filename}")
            print(f"  Location: {path}")
            print(f"  Size: {size:,} bytes")
    
    if not missing_in_splits and not extra_in_splits:
        print("No file differences found!")
        
        # Double-check file sizes
        size_mismatches = []
        for filename in original_files:
            orig_size = original_files[filename][0]
            split_size = split_files[filename][0]
            if orig_size != split_size:
                size_mismatches.append((filename, orig_size, split_size))
        
        if size_mismatches:
            print("\nFiles with different sizes:")
            for filename, orig_size, split_size in size_mismatches:
                print(f"- {filename}")
                print(f"  Original size: {orig_size:,} bytes")
                print(f"  Split size: {split_size:,} bytes")

if __name__ == "__main__":
    # Set your paths
    original_folder = r"F:\Proposal_merge_20344_orig"
    split_base_folder = r"F:"
    split_base_name = "Proposal_merge_20352_split"
    
    compare_folders(original_folder, split_base_folder, split_base_name)
# Out:
# Gathering files information...
# Original folder contains 20,336 files
# Split folders contain 20,335 files
#
# Comparison Results:
# --------------------------------------------------
#
# Files present in original but missing from splits:
# - Hirschmann_IT_USD_Q4-2021 (Regional).pdf
#   Location: F:\Proposal_merge_20344_orig\Hirschmann_IT_USD_Q4-2021 (Regional).pdf
#   Size: 192,826 bytes

# %% [markdown]
# ### Split doc to many smaller folders then convert to PDF

# %%
import os
import shutil
import subprocess
from pathlib import Path
import time
from datetime import datetime

class ConversionManager:
    def __init__(self, source_folder, temp_split_base, final_output_folder, num_splits=20):
        self.source_folder = Path(source_folder)
        self.temp_split_base = Path(temp_split_base)
        self.final_output_folder = Path(final_output_folder)
        self.num_splits = num_splits
        self.start_time = None
        
    def create_split_folders(self):
        """Create temporary folders for split files"""
        split_folders = []
        for i in range(self.num_splits):
            folder_path = self.temp_split_base / f"split_{i + 1}"
            folder_path.mkdir(parents=True, exist_ok=True)
            split_folders.append(folder_path)
        return split_folders
    
    def split_documents(self):
        """Split documents into multiple folders"""
        print("\n=== Splitting Documents ===")
        
        # Get all DOC/DOCX files
        doc_files = []
        for ext in ['.doc', '.docx', '.DOC', '.DOCX']:
            doc_files.extend(list(self.source_folder.glob(f"*{ext}")))
        
        doc_files.sort()
        total_files = len(doc_files)
        
        if total_files == 0:
            raise ValueError("No DOC/DOCX files found in source folder")
        
        print(f"Found {total_files} documents to process")
        
        # Create split folders
        split_folders = self.create_split_folders()
        
        # Calculate distribution
        base_files_per_folder = total_files // self.num_splits
        remainder = total_files % self.num_splits
        
        # Distribute files
        current_index = 0
        for folder_index, folder in enumerate(split_folders):
            # Calculate number of files for this folder
            files_for_folder = base_files_per_folder + (1 if folder_index < remainder else 0)
            
            print(f"\nPopulating split folder {folder_index + 1}/{self.num_splits}")
            print(f"Copying {files_for_folder} files...")
            
            # Copy files to this folder
            for _ in range(files_for_folder):
                if current_index < len(doc_files):
                    source_file = doc_files[current_index]
                    destination_file = folder / source_file.name
                    shutil.copy2(source_file, destination_file)
                    print(f"Copied: {source_file.name}")
                    current_index += 1
        
        return split_folders
    
    def convert_to_pdf(self, input_folder):
        """Convert DOC/DOCX files in a folder to PDF"""
        # Create temporary output folder for this split
        output_folder = input_folder.parent / f"{input_folder.name}_pdf"
        output_folder.mkdir(exist_ok=True)
        
        # Get all documents in this folder
        doc_files = []
        for ext in ['.doc', '.docx', '.DOC', '.DOCX']:
            doc_files.extend(list(input_folder.glob(f"*{ext}")))
        
        total_files = len(doc_files)
        successful = 0
        failed = []
        
        print(f"\nConverting {total_files} files in {input_folder.name}")
        
        # Use LibreOffice for conversion
        if os.name == 'nt':  # Windows
            soffice_path = r"C:\Program Files\LibreOffice\program\soffice.exe"
        else:  # Linux/Mac
            soffice_path = 'soffice'
        
        for idx, doc_file in enumerate(doc_files, 1):
            try:
                print(f"Converting {idx}/{total_files}: {doc_file.name}")
                
                subprocess.check_call([
                    soffice_path,
                    '--headless',
                    '--convert-to', 'pdf',
                    '--outdir', str(output_folder),
                    str(doc_file)
                ], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                
                successful += 1
                print(f"✓ Success: {doc_file.name}")
                
            except Exception as e:
                failed.append(doc_file.name)
                print(f"✗ Failed: {doc_file.name} - {str(e)}")
        
        return output_folder, successful, failed
    
    def merge_pdfs(self, pdf_folders):
        """Merge all PDFs into final output folder"""
        print("\n=== Merging PDFs ===")
        self.final_output_folder.mkdir(parents=True, exist_ok=True)
        
        total_copied = 0
        failed_copies = []
        
        for folder in pdf_folders:
            pdf_files = list(folder.glob('*.pdf'))
            for pdf_file in pdf_files:
                try:
                    destination = self.final_output_folder / pdf_file.name
                    shutil.copy2(pdf_file, destination)
                    total_copied += 1
                    print(f"Copied: {pdf_file.name}")
                except Exception as e:
                    failed_copies.append(pdf_file.name)
                    print(f"Failed to copy {pdf_file.name}: {str(e)}")
        
        return total_copied, failed_copies
    
    def cleanup_temp_folders(self, split_folders, pdf_folders):
        """Clean up temporary folders"""
        print("\n=== Cleaning up temporary folders ===")
        for folder in split_folders + pdf_folders:
            try:
                shutil.rmtree(folder)
                print(f"Removed: {folder}")
            except Exception as e:
                print(f"Failed to remove {folder}: {str(e)}")
    
    def process(self):
        """Main process to split, convert, and merge"""
        self.start_time = datetime.now()
        print(f"Starting process at: {self.start_time.strftime('%Y-%m-%d %H:%M:%S')}")
        
        try:
            # Split documents
            split_folders = self.split_documents()
            
            # Convert each split folder
            pdf_folders = []
            total_successful = 0
            all_failed = []
            
            for idx, folder in enumerate(split_folders, 1):
                print(f"\n=== Processing Split {idx}/{self.num_splits} ===")
                pdf_folder, successful, failed = self.convert_to_pdf(folder)
                pdf_folders.append(pdf_folder)
                total_successful += successful
                all_failed.extend(failed)
            
            # Merge PDFs
            total_merged, failed_merges = self.merge_pdfs(pdf_folders)
            
            # Cleanup
            self.cleanup_temp_folders(split_folders, pdf_folders)
            
            # Final report
            end_time = datetime.now()
            duration = end_time - self.start_time
            
            print("\n" + "=" * 50)
            print("FINAL REPORT")
            print("=" * 50)
            print(f"Process completed at: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Total duration: {duration}")
            print(f"\nConversion Results:")
            print(f"- Successfully converted: {total_successful}")
            print(f"- Failed conversions: {len(all_failed)}")
            print(f"- Total merged to final folder: {total_merged}")
            
            if all_failed:
                print("\nFailed conversions:")
                for file in all_failed:
                    print(f"- {file}")
            
            if failed_merges:
                print("\nFailed merges:")
                for file in failed_merges:
                    print(f"- {file}")
                    
        except Exception as e:
            print(f"\nCritical error: {str(e)}")
            raise

if __name__ == "__main__":
    try:
        # Define your paths here
        source = r"D:\fd_doc_Prop_1885_split3"  # Source folder with DOC files
        temp_base = r"D:\temp_conversion"  # Temporary folder for splits
        final_output = r"D:\fd_doc_Prop_1885_split3_to_pdf"  # Final output folder for all PDFs
        
        # Create and run converter
        converter = ConversionManager(
            source_folder=source,
            temp_split_base=temp_base,
            final_output_folder=final_output,
            num_splits=20  # Number of splits
        )
        
        converter.process()
        
    except Exception as e:
        print(f"Error: {str(e)}")
