# %% [markdown]
# ### Copy files from folder A to folder B

# %%
import shutil
import os

def copy_files(source_folder, destination_folder):
    # Check if the source folder exists
    if not os.path.exists(source_folder):
        print(f"Source folder '{source_folder}' does not exist.")
        return
    
    # Check if the destination folder exists, if not, create it
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Loop through each file in the source folder
    for filename in os.listdir(source_folder):
        source_file = os.path.join(source_folder, filename)
        destination_file = os.path.join(destination_folder, filename)

        # Check if it's a file (and not a subfolder)
        if os.path.isfile(source_file):
            shutil.copy(source_file, destination_file)
            print(f"Copied: {filename} to {destination_folder}")

source = r"D:\Vector Cloud\Proposal\1. Project\2016"
destination = r"F:\Proposal_16"

copy_files(source, destination)

# %% [markdown]
# ### Copy DOC files

# %%
import os
import shutil

def copy_doc_files_flat(source_folder, destination_folder):
    """
    Recursively copies all .doc and .docx files from the source folder and its subdirectories
    to the destination folder, without preserving directory structure.

    If there are duplicate filenames, the script renames the files to include part of the source path.

    Parameters:
        source_folder (str): The path to the folder containing the .doc and .docx files.
        destination_folder (str): The path to the folder where the files will be copied.
    """
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
        print(f"Created destination folder: {destination_folder}")

    for root, dirs, files in os.walk(source_folder):
        for filename in files:
            if filename.lower().endswith(('.doc', '.docx', '.DOC', 'DOCX')):
                source_file = os.path.join(root, filename)
                
                # Build a unique filename for the destination
                relative_path = os.path.relpath(root, source_folder)
                # Sanitize the relative path to create a safe filename
                safe_relative_path = relative_path.replace(os.sep, '_').replace('.', '_')
                name, ext = os.path.splitext(filename)
                new_filename = f"{name}_{safe_relative_path}{ext}"
                dest_file = os.path.join(destination_folder, new_filename)
                
                # Handle duplicate filenames by appending an index if necessary
                count = 1
                original_dest_file = dest_file
                while os.path.exists(dest_file):
                    new_filename = f"{name}_{safe_relative_path}_{count}{ext}"
                    dest_file = os.path.join(destination_folder, new_filename)
                    count += 1
                
                try:
                    shutil.copy2(source_file, dest_file)
                    print(f"Copied: {source_file} -> {dest_file}")
                except Exception as e:
                    print(f"Failed to copy {source_file}: {e}")

if __name__ == "__main__":
    # Replace these paths with your source and destination folders
    source_folder = r"D:\Vector Cloud\Procurement\Procurement"
    destination_folder = r"F:\doc_files_in_Procur"

    copy_doc_files_flat(source_folder, destination_folder)

# %% [markdown]
# ### Create a list to save PDF filename

# %%
import os

def get_store_pdf_filenames(folder_path):
    pdf_filenames = []
    
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith('.pdf'):
                pdf_filenames.append(file) 
    
    return pdf_filenames

# Example usage
folder_path = r"F:\Proposal_20_1587" # Change this to the folder you want to search
pdf_filenames_list = get_store_pdf_filenames(folder_path)

print(len(pdf_filenames_list))
pdf_filenames_list

# %%
import os
import shutil

# Replace these with your actual folder paths
# folder_A = r"F:\CT_in_Procur_merge_11186"
# folder_A = r"F:\Sale_merge_3807"
folder_A = r"F:\Proposal_merge_20352"

# folder_B = r"D:\Vector Cloud\Procurement\Procurement\2. Contract"
# folder_B = r"D:\Vector Cloud\Sales\3. SI Sales\1. SI"
folder_B = r"D:\Vector Cloud\Proposal\1. Project"


output_folder = './yeah'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Get list of PDF filenames in folder A (case-insensitive)
files_in_A = set(f.lower() for f in os.listdir(folder_A) if f.lower().endswith('.pdf'))

# Get all PDF files in folder B and its subfolders
files_in_B = []
for root, dirs, files in os.walk(folder_B):
    for file in files:
        if file.lower().endswith('.pdf'):
            files_in_B.append(os.path.join(root, file))

# Collect filenames (without path) of files in B
filenames_in_B = set(os.path.basename(f).lower() for f in files_in_B)

# Find the files that are in B but not in A
diff_filenames = filenames_in_B - files_in_A

# Now, from files_in_B, select the files whose basename is in diff_filenames
diff_files = [f for f in files_in_B if os.path.basename(f).lower() in diff_filenames]

# Copy the different files from B to the output folder, preserving relative paths
for src in diff_files:
    # Get the relative path of the file from folder B
    rel_path = os.path.relpath(src, folder_B)
    print(rel_path)
    dst = os.path.join(output_folder, rel_path)
    
    # Ensure the destination subfolder exists
    os.makedirs(os.path.dirname(dst), exist_ok=True)
    
    # Copy the file
    shutil.copy2(src, dst)

print(f"Copied {len(diff_files)} files to {output_folder}")

# %%
import os
import shutil

# Replace these with your actual folder paths
# folder_A = r"F:\CT_in_Procur_merge_11186"
# folder_A = r"F:\Sale_merge_3807"
folder_A = r"F:\Proposal_merge_20352"

# folder_B = r"D:\Vector Cloud\Procurement\Procurement\2. Contract"
# folder_B = r"D:\Vector Cloud\Sales\3. SI Sales\1. SI"
folder_B = r"D:\Vector Cloud\Proposal\1. Project"


output_folder = './yeah'
exclusion_folder = r"F:\file_can_pass_or_loi" # New variable for exclusion folder

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Get list of PDF filenames in folder A (case-insensitive)
files_in_A = set(f.lower() for f in os.listdir(folder_A) if f.lower().endswith('.pdf'))
excluded_filenames = set(f.lower() for f in os.listdir(exclusion_folder))  # Collect filenames to exclude

# Get all PDF files in folder B and its subfolders
files_in_B = []
for root, dirs, files in os.walk(folder_B):
    for file in files:
        if file.lower().endswith('.pdf'):
            files_in_B.append(os.path.join(root, file))

# Collect filenames (without path) of files in B
filenames_in_B = set(os.path.basename(f).lower() for f in files_in_B)

# Find the files that are in B but not in A
diff_filenames = filenames_in_B - files_in_A
diff_filenames = diff_filenames - excluded_filenames  # Adjusted line to exclude files

# Now, from files_in_B, select the files whose basename is in diff_filenames
diff_files = [f for f in files_in_B if os.path.basename(f).lower() in diff_filenames]

# Copy the different files from B to the output folder, preserving relative paths
for src in diff_files:
    # Get the relative path of the file from folder B
    rel_path = os.path.relpath(src, folder_B)
    print(rel_path)
    dst = os.path.join(output_folder, rel_path)
    
    # Ensure the destination subfolder exists
    os.makedirs(os.path.dirname(dst), exist_ok=True)
    
    # Copy the file
    shutil.copy2(src, dst)

print(f"Copied {len(diff_files)} files to {output_folder}")
# Out:
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\CPP PAGA BLOCK DIAGRAM.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\CPP_BEACON LOCATION.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LQ PAGA BLOCK DIAGRAM.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LQ_BEACON LOCATION.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\PAGA REVISED QTY.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\Palo Alto Firewall Specification.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\PQ-CPC0-ELE-SPC-MPC-00008-00_N01_Electrical Distribution Board.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\FIREWALL ARCHITECTURE\UPDATED FIREWALL SCHEMATIC.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\HOTLINE SYSTEM ARCHITECTURE\HOTLINE ARCHITECTURE.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-ARC-GAR-MPC-00001-00_MEZZANINE DECK OFFICE LAB.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-ICS-LAY-MPC-00001-00_MEZZANINE DECK EQUIPMENT ROOM IER CCR.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00002-01_WEATHER DECK NORTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00003-01_WEATHER DECK SOUTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00004-01_MAIN DECK NORTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00005-01_MAIN DECK SOUTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00006-01_MEZZANINE DECK NORTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00007-01_MEZZANINE DECK SOUTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00008-01_CELLAR DECK NORTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00009-01_CELLAR DECK SOUTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00010-01_SUB CELLAR DECK NORTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00011-01_SUB CELLAR DECK SOUTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00012-01_SEA DECK NORTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00013-01_SEA DECK SOUTH.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00017-01_CPP TO AQWA BRIDGE.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\CPP\PQ-CPPT-PIP-LAY-MPC-00019-01_CPP TO LQ LINK BRIDGE.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQM\PQ-CLQ0-ICS-LAY-MPC-00001-00_EQUIPMENT ROOM LAYOUT (DRAFT).pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQM\PQ-CLQM-ARC-GAR-MPC-00001-00_LEVEL 1.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQM\PQ-CLQM-ARC-GAR-MPC-00002-00_LEVEL 2.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQM\PQ-CLQM-ARC-GAR-MPC-00003-00_LEVEL 3.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQM\PQ-CLQM-ARC-GAR-MPC-00004-00_LEVEL 4.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQM\PQ-CLQM-ARC-GAR-MPC-00005-00_LEVEL 5.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQM\PQ-CLQM-ARC-GAR-MPC-00006-00_ROOF.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQM\PQ-CLQM-ARC-GAR-MPC-00007-00_HELIDECK.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQU\PQ-CLQ0-ICS-LAY-MPC-00001-01_CELLAR DECK - INSTRUMENT ROOM.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQU\PQ-CLQU-ARC-GAR-MPC-00001-00_CELLAR DECK - ELECTRICAL ROOM.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQU\PQ-CLQU-ARC-GAR-MPC-00002-00_MEZZANINE DECK CRANE OFFICE LAUNDRY.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQU\PQ-CLQU-PIP-LAY-MPC-00014-01_JACKET WALKWAY & BOAT LANDING.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQU\PQ-CLQU-PIP-LAY-MPC-00015-01_SUB CELLAR DECK.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQU\PQ-CLQU-PIP-LAY-MPC-00016-01_CELLAR DECK.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQU\PQ-CLQU-PIP-LAY-MPC-00017-01_MEZZANINE DECK.pdf
# 2024\15. McDermott - Block B - Offshore\5. BCM\RFQ\Vector Infotech\Attachments\LAYOUTS\LQU\PQ-CLQU-PIP-LAY-MPC-00018-01_UPPER DECK.pdf
# 2024\23. VSP - Thien Nga Hai Au\0. RFQ\Official RFQ\WHP-TNHAU-BID-EQU-1002_TR for Telecommunication system_20241003.pdf
# 2024\23. VSP - Thien Nga Hai Au\0. RFQ\Official RFQ\[signed} RFQ_III.2_Telecommunication system.pdf
# 2024\23. VSP - Thien Nga Hai Au\0. RFQ\Official RFQ\Appendix 1_ Technical documents\9001-2202-DK-0001-01 B1 TELECOMMUNICATION OVERALL BLOCK DIAGRAM (BK-TN).pdf
# 2024\23. VSP - Thien Nga Hai Au\0. RFQ\Official RFQ\Appendix 1_ Technical documents\Telecommuniocation System\BK-TNHA\Specification\9001-2201-AE-0001 B1 ELECTRICAL DESIGN BASIS (BK-TNHA) - signed.pdf
# 2024\23. VSP - Thien Nga Hai Au\0. RFQ\Official RFQ\Appendix 1_ Technical documents\Telecommuniocation System\BK-TNHA\Specification\9001-2201-RJ-0002 B1 INSTRUMENT CONTROL NARRATIVE (BK-TNHA) - signed.pdf
# 2024\23. VSP - Thien Nga Hai Au\0. RFQ\Official RFQ\Appendix 1_ Technical documents\Telecommuniocation System\BK-TNHA\Specification\9001-2201-SE-0004 B1 SPECIFICATION FOR CABLES (BK-TNHA) - signed.pdf
# 2024\23. VSP - Thien Nga Hai Au\0. RFQ\Official RFQ\Appendix 1_ Technical documents\Telecommuniocation System\RD-HTI\DRAWING\TELECOM LAYOUT & LIST\VN01-230-C-DW-1203-01 B1 TELECOM LOCATION PLAN (LQ) - signed.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 1 Thuyết minh chung\P1T1 Phần 1 Thuyết minh BCNCKT - Tập 1 Thuyết minh chung.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q1 - Cac Van ban phap ly P1-T2-Q2.1.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q2 - Bao cao cung cap nhien lieu P1-T2-Q2.2.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q3 - Thuyet minh PCCC P1-T2-Q2.3.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q4.1 Bao cao khảo sát thủy văn P1-T2-Q2.4.1.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q4.2 Bao cao khao sat dia chat 1 P1-T2-Q2.4.2.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q4.3 Bao cao khao sat dia chat 2 P1-T2-Q2.4.3.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q4.4 Bao cao khao sat dia chat 3 P1-T2-Q2.4.4.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q5 - Bao cao dau noi HTDQG P1-T2-Q2.5.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q6 - Bao cao dau noi SCADA & TTLL P1-T2-Q2.6.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q7 - Bao cao do dem dien nang P1-T2-Q2.7.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 1\Phần 1 - Thuyết minh BCNCKT - Tập 2 Báo cáo chuyên ngành\P1T2Q8 - Bao cao danh gia tac dong MT P1-T2-Q2.8.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 2\Phần 2 - Thiết kế cơ sở - Tập 3 Các bản vẽ.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 2\Phần 2 - Thiết kế cơ sở - Tập 1 Thuyết minh thiết kế\P2T1 - Phần 2 Thiết kế cơ sở - Tập 1 Thuyết minh thiết kế.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 2\Phần 2 - Thiết kế cơ sở - Tập 2 Các phụ lục tính toán\P2T2Q1 - Phụ lục tính toán công nghệ và điện P2-T2-Q2.1.pdf
# 2024\26. OMON 4\RFQ\File_IB2400360324 (1)\File_IB2400360324\FEASIBILYTY STUDY O MON IV - Part 2\Phần 2 - Thiết kế cơ sở - Tập 2 Các phụ lục tính toán\P2T2Q2 - Phụ lục tính toán xây dựng P2-T2-Q2.2.pdf
# 2024\26. OMON 4\RFQ\Prepare\P1T2Q6 - Bao cao dau noi SCADA & TTLL P1-T2-Q2.6.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIIS5 - Electrical Plant - Telecom scope.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIIS5 - TS for Electrical Plant - Communication system.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\1.General\OMIV-RFP-G-001 Location of O MON Power Complex.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\1.General\OMIV-RFP-G-002 General layout of OMON IV TPP.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\1.General\OMIV-RFP-G-003 Plant layout of OMON IV TPP.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\1.General\OMIV-RFP-G-004 Technical corridor & terminal points.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-002 Steam-Water cycle flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-003 Feedwater pump system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-004 Condensate forwarding pump diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-005.1 Lubrication oil system flow diagram (Gas turbine).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-005.2 Lubrication oil system flow diagram (Steam turbine).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-006 Gas turbine De-NOx water spray diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-007 Circulating cooling water system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-008 Closed Circulating cooling water system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-009 Water treatment system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-010.1 Water balancing diagram (Gas burning).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-010.2 Water balancing diagram (DO burning).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-011 Natural gas supply system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-012 DO supply system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-013 Raw water treatment system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-014.1 Wastewater treatment system flow diagram (plant).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-014.2 Wastewater treatment system flow diagram (domestic).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-015 Compressed air supply system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-016 - Sampling system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-017 Photphate dosing system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-018 Hydrogen supply system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-019 Ammonia and Carbohydrazide dosing system flow diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\2.Mechanical\OMIV-RFP-M-020 Hydralic diagram of fire water supply piping system.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-01 - Symbols & Legend for electrical system.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-02 - Existing electric system diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-03 - Geographical map of Mekong delta area.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-04 - Single line diagram of Mekong delta area (2030).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-05 - Single line diagram of power plant.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-06 - O Mon 500kV Substation single line diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-07 - O Mon 500kV Substation layout.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-08 - Single line diagram Auxiliary system.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-09 - Invesment boundary of project.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-10 - Operation management boundary of project.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-11 - Connection points of power system.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-12 - Metering and relay protection diagram for Gas Turnine Generator Unit.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-13 - Metering and relay protection diagram for Steam Turnine Generator Unit.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-14 - Metering and relay protection diagram for O Mon 500kV Substation.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-15 - Tariff metering location.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-16 - Construction power supply.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-17 - Relay protection principle for Auxiliary system.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\3.Electrical\OMIV-RFP-EL-18 - Control and protection connection to O Mon 500kV Substation.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\4.DCS\OMIV-RFP-CO-01_Local Telecommunication Network Diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\4.DCS\OMIV-RFP-CO-02_Local Telecommunication & SCADA System Diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\4.DCS\OMIV-RFP-CO-03_Power Supply Principle Diagram.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\4.DCS\OMIV-RFP-IC-01-Control System Diagram_R.B_(1-2).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\4.DCS\OMIV-RFP-IC-01-Control System Diagram_R.B_(2-2).pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\4.DCS\OMIV-RFP-IC-02-Control Room Arrangement_layout.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-01-01-A-CIVIL GENERAL LAYOUT.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-01-03-Stormwater Drainage-EPC.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-01-05-A-GENERAL CONSTRUCTION PLANT.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-01-06-Anti-Erosion Embankment.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-01-07- Commom item constructed by Owner.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-02-02-C-Gas Turbine Generator - Foundation.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-02-03-C-Steam Turbine Generator - Foundation.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-02-05-A-CENTRAL CONTROL BUILDING.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-02-05-C-Central Control Building.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-03-01-C-Main Transformer - Foundation.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-03-02-C-Unit Auxiliary Transformer - Foundation.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-03-03-500kV Substation - Foundation Layout.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-03-04-500kv Substation - Equipment Foundation.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-03-05-500kv Substation - Gantry Tower.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-03-06-500kv Substation - Equipment Support Structures.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-03-07-Transformer Oil Storage Tank.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-04-01-Cooling Water Pipeline.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-04-03-Cooling Water Discharge Culvert.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-04-05-Cooling Water Discharge Channel.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-05-01-A-WATER TREATMENT BUILDING.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-05-01-C-Water Treatment Building.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-05-02-Water Treatment Area.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-01-C-Diesel Generation Station.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-02-A-GAS DISTRIBUTION STATION.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-02-C-Gas Distribution Staion.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-03-A-GAS TREATMENT STATION.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-03-C-Gas Treatment Staion.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-04 -A-AIR COMPRESSOR HOUSE.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-04-C-Air Compressor House.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-05-A-FIRE-FIGHTING PUMP HOUSE.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-05-C-Fire-Fighting Pump House.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-06-A-HYDROGEN STATION.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-06-C-Hydrogen Station.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-08-Foundation for Fire Protection Pipeline.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-09-A-FEED WATER PUMP HOUSE.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-06-09-C-Feed Water Pump House.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-01-A-ADMINISTRATION BUILDING.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-01-C-Administration Building.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-05-A-MOTORCYCLE SHED.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-05-C-Motorcycle Shed.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-06-A-FIRE TRUCK GARAGE.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-06-C-Fire Truck Garage.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-11-A-OIL PUMP STATION.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-11-C-Oil Pump Station.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-12-A-OIL MEASUREMENT STATION.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-12-Oil Measurement Station.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-13-A-CHEMICAL LABORATORY HOUSE.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-13-C-Chemical Laboratory House.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-14-A-HAZARDOUS WASTE STORAGE HOUSE.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-14-Hazardous Waste Storage House.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-16-Oil Collecting Tank.pdf
# 2024\26. OMON 4\RFQ\Prepare\P2CVIII Bid Drawings\5.Civil\OMIV-RFP-CA-HMDC-17-A-SITE OFFICE FOR OWNER AND CONSULTANT.pdf
# 2024\28. Saipem - Angola\0. RFQ\001 RFQ\AO-400-10-SA00-491201_00_IFI_BOM List.pdf
# 2024\29. Petrolimex Can Tho - Tu DK BOM PCCC\Bom PCCC\Bao gia Tu DK PCCC - Petrolimex - Rev0.pdf
# 2024\29. Petrolimex Can Tho - Tu DK BOM PCCC\Bom PCCC\TCVN5307_2009_904331.pdf
# Copied 172 files to ./yeah

# %%
import os
import shutil

# Define the sets of folder paths
set1 = [
    r"F:\CT_in_Procur_merge_11186",
    r"F:\Proposal_merge_20352",
    r"F:\Sale_merge_3807"  
]

set2 = [
    r"D:\Vector Cloud\Procurement\Procurement\2. Contract",
    r"D:\Vector Cloud\Proposal\1. Project",
    r"D:\Vector Cloud\Sales\3. SI Sales\1. SI"  
]
# Define the main output folder
updated_fd = r"./updated_fd"
os.makedirs(updated_fd, exist_ok=True)
exclusion_folder = r"F:\file_can_pass_or_loi" # New variable for exclusion folder


# Check that both sets have the same number of folders
if len(set1) != len(set2):
    raise ValueError("Both sets of folders must have the same number of folders.")

# Loop over the pairs of folders
for idx, (folder_A, folder_B) in enumerate(zip(set1, set2), start=0):
    # Create a subfolder for this pair within the main output folder
    name_A = os.path.basename(os.path.normpath(folder_A))
    name_B = os.path.basename(os.path.normpath(folder_B))
    pair_folder_name = f"{name_A}_vs_{name_B}"
    output_folder = os.path.join(updated_fd, pair_folder_name)
    os.makedirs(output_folder, exist_ok=True)

    # Ensure that folder_A and folder_B exist
    if not os.path.exists(folder_A):
        print(f"Folder A does not exist: {folder_A}")
        continue
    if not os.path.exists(folder_B):
        print(f"Folder B does not exist: {folder_B}")
        continue

    # Get list of PDF filenames in folder A (case-insensitive)
    files_in_A = set(f.lower() for f in os.listdir(folder_A) if f.lower().endswith('.pdf'))
    excluded_filenames = set(f.lower() for f in os.listdir(exclusion_folder))  # Collect filenames to exclude

    # Get all PDF files in folder B and its subfolders
    files_in_B = []
    for root, dirs, files in os.walk(folder_B):
        for file in files:
            if file.lower().endswith('.pdf'):
                files_in_B.append(os.path.join(root, file))

    # Collect filenames (without path) of files in B
    filenames_in_B = set(os.path.basename(f).lower() for f in files_in_B)

    # Find the files that are in B but not in A
    diff_filenames = filenames_in_B - files_in_A

    # Now, from files_in_B, select the files whose basename is in diff_filenames
    diff_files = [f for f in files_in_B if os.path.basename(f).lower() in diff_filenames]
    diff_filenames = diff_filenames - excluded_filenames  # Adjusted line to exclude files

    # Copy the different files from B to the output folder, preserving relative paths
    for src in diff_files:
        # Get the relative path of the file from folder B
        rel_path = os.path.relpath(src, folder_B)
        dst = os.path.join(output_folder, rel_path)

        # Ensure the destination subfolder exists
        os.makedirs(os.path.dirname(dst), exist_ok=True)

        # Check if the source file exists
        if not os.path.exists(src):
            print(f"Source file does not exist: {src}")
            continue

        # Copy the file
        try:
            shutil.copy2(src, dst)
        except Exception as e:
            print(f"Error copying {src} to {dst}: {e}")

    print(f"Copied {len(diff_files)} files for pair {idx} ({name_A} vs {name_B}) to {output_folder}")

# %%
from byaldi import RAGMultiModalModel
from dotenv import load_dotenv
import PIL.Image

load_dotenv()
hf_token = os.getenv("HF_TOKEN")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")
os.environ["HF_TOKEN"] = hf_token
os.environ["ANTHROPIC_API_KEY"] = anthropic_api_key

PIL.Image.MAX_IMAGE_PIXELS = None
attention_path = r"D:\first_docu\attn_fd\attn_CT_all_2032024_cp1"
RAG = RAGMultiModalModel.from_index(attention_path, verbose=1)
len(RAG.get_doc_ids_to_file_names())
