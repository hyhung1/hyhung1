# %%
import os
import subprocess
import sys

def doc_to_pdf(doc_path, output_dir, current_count, total_files):
    """
    Converts a Word document to PDF using LibreOffice command-line tools.

    Parameters:
        doc_path (str): The path to the input .doc or .docx file.
        output_dir (str): The directory where the output PDF will be saved.
        current_count (int): Current number of successful conversions
        total_files (int): Total number of files to process
    """
    try:
        # Get the original filename without extension
        original_filename = os.path.splitext(os.path.basename(doc_path))[0]
        
        # Create a temporary directory for conversion
        temp_dir = os.path.join(output_dir, "_temp")
        os.makedirs(temp_dir, exist_ok=True)
        
        # For Windows, you'll need to specify the full path to soffice.exe
        if os.name == 'nt':  # Windows
            soffice_path = r"C:\Program Files\LibreOffice\program\soffice.exe"
        else:  # Linux/Mac
            soffice_path = 'soffice'

        # Convert to PDF in temporary directory
        subprocess.check_call([
            soffice_path,
            '--headless',
            '--convert-to', 'pdf',
            '--outdir', temp_dir,
            doc_path
        ], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        
        # Find the converted file in temp directory (it will be lowercase)
        temp_pdf = os.path.join(temp_dir, os.path.splitext(os.path.basename(doc_path))[0].lower() + '.pdf')
        
        # Move to final destination with original case
        final_pdf = os.path.join(output_dir, original_filename + '.pdf')
        os.replace(temp_pdf, final_pdf)
        
        # Remove temporary directory if empty
        try:
            os.rmdir(temp_dir)
        except OSError:
            pass  # Directory not empty or already deleted
            
        print(f"[{current_count + 1}/{total_files}] Successfully converted: {os.path.basename(doc_path)}")
        return True
    except subprocess.CalledProcessError as e:
        print(f"Failed to convert {os.path.basename(doc_path)}: {e}")
        return False
    except Exception as e:
        print(f"Error processing {os.path.basename(doc_path)}: {e}")
        return False

def batch_convert_docs(folder_path, output_dir):
    """
    Converts all .doc and .docx files in a folder to PDF using LibreOffice,
    and stores the PDFs in the specified output directory.

    Parameters:
        folder_path (str): The path to the folder containing Word documents.
        output_dir (str): The directory where the output PDFs will be saved.
    """
    # Ensure paths exist
    if not os.path.exists(folder_path):
        raise FileNotFoundError(f"Input folder not found: {folder_path}")

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    print(f"Output directory ready: {output_dir}")

    # First count total files
    total_files = sum(1 for root, _, files in os.walk(folder_path)
                     for filename in files
                     if filename.lower().endswith(('.doc', '.docx')))

    print(f"\nFound {total_files} documents to convert")
    print("Starting conversion process...\n")

    # Track conversion statistics
    successful_conversions = 0
    failed_conversions = 0

    # Process all files
    for root, _, files in os.walk(folder_path):
        for filename in files:
            if filename.lower().endswith(('.doc', '.docx')):
                doc_path = os.path.join(root, filename)
                if doc_to_pdf(doc_path, output_dir, successful_conversions, total_files):
                    successful_conversions += 1
                else:
                    failed_conversions += 1

    # Print summary
    print("\nConversion Summary:")
    print(f"Total files found: {total_files}")
    print(f"Successfully converted: {successful_conversions}")
    print(f"Failed conversions: {failed_conversions}")

    # Calculate success rate
    if total_files > 0:
        success_rate = (successful_conversions / total_files) * 100
        print(f"Success rate: {success_rate:.1f}%")

if __name__ == "__main__":
    # Define your local paths here
    folder_path = r"F:\orig\CT_doc_files" # Change this
    output_dir = r"F:\orig\CT_doc_files_to_pdf"  # Change this
    os.makedirs(output_dir, exist_ok=True)

    # Verify paths exist
    if not os.path.exists(folder_path):
        print(f"Error: Input folder not found: {folder_path}")
        sys.exit(1)

    print(f"Starting conversion process...")
    print(f"Input folder: {folder_path}")
    print(f"Output folder: {output_dir}")

    try:
        batch_convert_docs(folder_path, output_dir)
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Starting conversion process...
# Input folder: F:\orig\CT_doc_files
# Output folder: F:\orig\CT_doc_files_to_pdf
# Output directory ready: F:\orig\CT_doc_files_to_pdf
#
# Found 1718 documents to convert
# Starting conversion process...
#
# [1/1718] Successfully converted: ! Vilas 60 HƯỚNG DẪN CHI TIẾT ĐO KIỂM.docx
# [2/1718] Successfully converted: !!! Hop chuan, hop quy, do kiem.docx
# [3/1718] Successfully converted: !!! Note.docx
# [4/1718] Successfully converted: #10_HD VMPC-VECTOR 20231003 (FINAL).doc
# [5/1718] Successfully converted: (RV1)HỢP ĐỒNG AMIVN- VECTOR cmt.docx
# [6/1718] Successfully converted: 0. Bang ke chung tu thuoc Phu luc III.doc
# [7/1718] Successfully converted: 0. Phụ lục HD 03_V2_Vector cmt.doc
# [8/1718] Successfully converted: 01.PLDC.docx
# [9/1718] Successfully converted: 0110-HĐMB-KTV-VIVN-2024 - cmt.doc
# [10/1718] Successfully converted: 01_Purchase Contract_Terms  Conditions_G2.docx
# [11/1718] Successfully converted: 02_Exhibit I_Schedule of Rates  Prices_G2.docx
# [12/1718] Successfully converted: 03. Bao cao tong hoat do, luong hoat do ban giao.doc
# [13/1718] Successfully converted: 037622-HBMB-KD-Contract Vector_Long Son Petrochemicals ND.doc
# [14/1718] Successfully converted: 042-Contract-Omnitech-102014 (rev1).docx
# [15/1718] Successfully converted: 042-Contract-Omnitech-102014 (rev2) on Oct 29 by Ngoc - Copy.docx
# [16/1718] Successfully converted: 042-Contract-Omnitech-102014 (rev3) on Nov 14 by Ngoc FINAL.docx
# [17/1718] Successfully converted: 05.2014.TT.BTTTT.doc
# [18/1718] Successfully converted: 05.2014.TT.BTTTT.Phu luc.doc
# [19/1718] Successfully converted: 1  Don nhap khau  - done.doc
# [20/1718] Successfully converted: 1 TĐG RLX2-IHNF-A.docx
# [21/1718] Successfully converted: 1-HOADON_nhap Emerson.doc
# [22/1718] Successfully converted: 1-HOADON_nhap Petronas - antennas.doc
# [23/1718] Successfully converted: 1-HOADON_nhap Petronas - hang hoa.doc
# [24/1718] Successfully converted: 1-HOADON_nhap Petronas - Service 2.doc
# [25/1718] Successfully converted: 1-HOADON_nhap Petronas .doc
# [26/1718] Successfully converted: 1-HOADON_nhap Petronas.doc
# [27/1718] Successfully converted: 1-HOADON_nhap.doc
# [28/1718] Successfully converted: 1. 003 - VIV - S-A form - MS20.docx
# [29/1718] Successfully converted: 1. 003 - VIV - S-A form - RS20.docx
# [30/1718] Successfully converted: 1. 003 - VIV - S-A form - Spider.docx
# [31/1718] Successfully converted: 1. 005 - VIV - S-A form.docx
# [32/1718] Successfully converted: 1. bao cao ap tai.doc
# [33/1718] Successfully converted: 1. CCTV_Thoa thuan Hop dong.docx
# [34/1718] Successfully converted: 1. DKKT CL - FZ-G1 - VIV.doc
# [35/1718] Successfully converted: 1. DKKT CL - Vietsov.doc
# [36/1718] Successfully converted: 1. DKKT CL - VIV.doc
# [37/1718] Successfully converted: 1. Don Dang ky KT CL - VIV.doc
# [38/1718] Successfully converted: 1. FOPP TO SWITCH (1 TO 2) x 1 set.docx
# [39/1718] Successfully converted: 1. FZ-G1 - VIV - S-A form.docx
# [40/1718] Successfully converted: 1. Minutes of Meeting.docx
# [41/1718] Successfully converted: 1. Trang bìa.doc
# [42/1718] Successfully converted: 1. WIRING TAG_CCTV (From 1 to 2).docx
# [43/1718] Successfully converted: 1. ĐKKTCL RLX2-IHNF-A .docx
# [44/1718] Successfully converted: 1. Đơn xin cấp CNHQ RLX2-INHF-A.docx
# [45/1718] Successfully converted: 1.mau 01 Quyet dinh KTSTQ. doc.doc
# [46/1718] Successfully converted: 106_2022_HDMB_123CORP_VECTOR.doc
# [47/1718] Successfully converted: 10_230607_BSR-HSE-PRO-015_F-005_Giay phep van chuyen thiet bi vat tu tai BSR Rev 5_0210.doc
# [48/1718] Successfully converted: 113_2017_nd-cp_346246.doc
# [49/1718] Successfully converted: 11_230607_BSR-HSE-PRO-015_F-006_Dang_ky_phuong_tien_giao_thong_vao_nha_may - Rev 5.docx
# [50/1718] Successfully converted: 11_230607_BSR-HSE-PRO-015_F-006_Dang_ky_phuong_tien_giao_thong_vao_nha_may - Rev 5_0210.docx
# [51/1718] Successfully converted: 13. Thong bao phe duyet khai bao van chuyen.doc
# [52/1718] Successfully converted: 14. Thong bao phe duyet lai khai bao van chuyen.doc
# [53/1718] Successfully converted: 16-0010_Vector Infotech_LCD DELL  Cisco Router_04-2016.doc
# [54/1718] Successfully converted: 16-0042_Vector Infotech_Cisco Switch_11-2016 - Revised.doc
# [55/1718] Successfully converted: 1603008-Contract-TANTIEN_VIVN-150316(rev1).doc
# [56/1718] Successfully converted: 171207 - draft bien ban phat giao hang cham - rev 1.docx
# [57/1718] Successfully converted: 180525 - Document transmittal.docx
# [58/1718] Successfully converted: 195363-VXM-06-LS-7604_CP.doc
# [59/1718] Successfully converted: 195363-VXM-06-QC-7610_CP.doc
# [60/1718] Successfully converted: 195363-VXM-06-QC-7620_CP.doc
# [61/1718] Successfully converted: 195363-VXM-06-QC-7621_CP.doc
# [62/1718] Successfully converted: 195363-VXM-06-QC-7622_CP.doc
# [63/1718] Successfully converted: 195363-VXM-06-QC-7623_CP - Copy.doc
# [64/1718] Successfully converted: 195363-VXM-06-QC-7623_CP.doc
# [65/1718] Successfully converted: 195363-VXM-06-RP-7604_CP.doc
# [66/1718] Successfully converted: 2. CCTV_Cac dieu kien cua Hop dong_Checked_cleaned.docx
# [67/1718] Successfully converted: 2. Decision.docx
# [68/1718] Successfully converted: 2. PO.docx
# [69/1718] Successfully converted: 2. UPSC - Ver#1.doc
# [70/1718] Successfully converted: 2. UTTP TO 8-PORT SWITCH (1 TO 2) - x 23 set .docx
# [71/1718] Successfully converted: 2. WIRING TAG_CCTV (To 2 from 1).docx
# [72/1718] Successfully converted: 2.mau 02 THONG BAO thu thap TT.doc
# [73/1718] Successfully converted: 20-0011_Vector Infotech_Cisco Router 2911_09-2020.doc
# [74/1718] Successfully converted: 2014-4976-4W-0301 Rev B Material requisition for PAGA system.docx
# [75/1718] Successfully converted: 2014-4976-4W-0301 Rev.C Material requisition for PAGA system.docx
# [76/1718] Successfully converted: 2019_NEXTGEN-VECTOR_Provision of Flame Detector_Rev A.doc
# [77/1718] Successfully converted: 2020-07-24 MẪU GIẤY YCBH AIR_VECTOR INFOTECH.doc
# [78/1718] Successfully converted: 2020-08-17 MẪU GIẤY YCBH AIR_VECTOR INFOTECH.doc
# [79/1718] Successfully converted: 2021 HHNK P001763_VECTOR_USA (002).doc
# [80/1718] Successfully converted: 2021-07-09 CÔNG VĂN CAM KẾT.doc
# [81/1718] Successfully converted: 2022-10-18 Hợp đồng mua bán thiết bị điện.doc
# [82/1718] Successfully converted: 2023 05 12_C32_HHVC_VECTOR.cmt.doc
# [83/1718] Successfully converted: 2023 05 12_C32_HHVC_VECTOR.doc
# [84/1718] Successfully converted: 2023 10 04 HD thiet bi GW Vector-NDG - rv1.doc
# [85/1718] Successfully converted: 2023 HHNK PC00628_USA_AIR CPN.cmt.doc
# [86/1718] Successfully converted: 2023 VCND PC00072.doc
# [87/1718] Successfully converted: 2023-Muc Luc Ho Son Ban Le va Dich Vu.docx
# [88/1718] Successfully converted: 2024 10 09 HD thiet bi OpenScape Vector-NDG - chia bill.doc
# [89/1718] Successfully converted: 2024 10 09 HD thiet bi OpenScape Vector-NDG - rv1-final.doc
# [90/1718] Successfully converted: 2024 HHNK PC00043_UK_AIR (002)cmt.doc
# [91/1718] Successfully converted: 20242602-HDKT Vector InfoTech -TMG (CISCO ).doc
# [92/1718] Successfully converted: 2104022-01-VECTOR-TK.docx
# [93/1718] Successfully converted: 24-0008_Vector Infotech_Cisco Router 2911_06-2024.doc
# [94/1718] Successfully converted: 251121 - Contract Amendment No 01 - COVID 19 Expense - 016E.doc
# [95/1718] Successfully converted: 3.  Bank Account confirmed by Tax office.doc
# [96/1718] Successfully converted: 3. 5. Busniess license translated.docx
# [97/1718] Successfully converted: 3. Chap nhan BT va chuyển quyền khiếu nại _VECTOR PC00738.doc
# [98/1718] Successfully converted: 3. Hop dong-ghi am dien thoi.docx
# [99/1718] Successfully converted: 3. Notice_business line.doc
# [100/1718] Successfully converted: 3. UTTP TO 16-PORT SWITCH (1 TO 2) - x 2 set.docx
# [101/1718] Successfully converted: 3.1 MOM - Vector Infotech.doc
# [102/1718] Successfully converted: 3.1. CCTV_Phu luc 1 - Pham vi cong viec.docx
# [103/1718] Successfully converted: 3.1. MOM - Vector Infotech - Attachment.docx
# [104/1718] Successfully converted: 3.1.1 CCTV_Attachment #1-Detail Scope of Work.doc
# [105/1718] Successfully converted: 3.1.2 CCTV_Attachment #2-Interface.docx
# [106/1718] Successfully converted: 3.2. CCTV_Phu luc 2_Dieu khoan va quy trinh thanh toan_Checked_cleaned.docx
# [107/1718] Successfully converted: 3.5. CCTV_Phu luc 5. Bieu mau.doc
# [108/1718] Successfully converted: 3.mau 03 Quyet dinh sưa doi bo sung QD KTSTQ.3.doc
# [109/1718] Successfully converted: 30.2011.TT.BTTTT.doc
# [110/1718] Successfully converted: 30_2011_TT-BTTTT[1].doc
# [111/1718] Successfully converted: 4  Don van chuyen - done (2).doc
# [112/1718] Successfully converted: 4. Att. 2 - Packing and Marking -VAT with PO No.docx
# [113/1718] Successfully converted: 4. HD UY THAC PVEPPOC.doc
# [114/1718] Successfully converted: 4. Mẫu CV đăng ký dấu hợp quy_Cuc Vien thong (Form mới).doc
# [115/1718] Successfully converted: 4. Power of attorney.doc
# [116/1718] Successfully converted: 4. Sample RLX2-IHNF-A.docx
# [117/1718] Successfully converted: 4. SBP_HOP DONG M&E ISD Feb 3 2021.doc
# [118/1718] Successfully converted: 4. SBP_HOP DONG M&E ISD.doc
# [119/1718] Successfully converted: 4. SBP_HOP DONG M&E NHÃ_P.doc
# [120/1718] Successfully converted: 4.mau 04 quyet dinh gia han.4.doc
# [121/1718] Successfully converted: 466 Vector InfoTech - Digital Pressure Gauge XP2i-cmt.docx
# [122/1718] Successfully converted: 5. BẢN ẢNH MÔ TẢ DÁN NHÃN HÀNG HÓA MÁY TÍNH BẢNG FZ.doc
# [123/1718] Successfully converted: 5. GIAY GIOI THIEU VECTOR.doc
# [124/1718] Successfully converted: 5. UTTP TO SWITCH (1 TO 2) - Admin - 2F x 1 set.docx
# [125/1718] Successfully converted: 5. VC_SEHC to SS partners_2023_Revised by RM & Legal_Final version_June 6.docx
# [126/1718] Successfully converted: 5.mau 05 Ban KLKT.doc
# [127/1718] Successfully converted: 58- Mẫu 4 - Đơn xin cấp GPNK.docx
# [128/1718] Successfully converted: 580-Contract-HoangLe_VIVN-Westermo-160915.docx
# [129/1718] Successfully converted: 5825_TCHQ-GSQL_497363.doc
# [130/1718] Successfully converted: 58_2016_ND-CP.doc
# [131/1718] Successfully converted: 6  HD contract .doc
# [132/1718] Successfully converted: 6. GIAY GIOI THIEU Vector.DOC
# [133/1718] Successfully converted: 6. UTTP TO SWITCH (1 TO 2) - Admin - GF x 1 set.docx
# [134/1718] Successfully converted: 6.Mau 06 thong bao ket qua kiem tra.QT.doc
# [135/1718] Successfully converted: 640-Contract-Sytek_VIVN-Westermo-190416.docx
# [136/1718] Successfully converted: 6_230607_BSR-HSE-PRO-015_F-001_Dang_ky yeu cau vao Nha may - Rev 5_0210.doc
# [137/1718] Successfully converted: 7  Bien_ban_dam_phan - A.DOC
# [138/1718] Successfully converted: 7-2020-06-15-pl-vii-mau-loi-van-khai-bao-xuat-xu-clean-version.docx
# [139/1718] Successfully converted: 7. UTTP TO SWITCH (1 TO 2) - CCB x 1 set.docx
# [140/1718] Successfully converted: 7.mau 07 QD HUY  kiem tra.9.doc
# [141/1718] Successfully converted: 75-LuậtTiêu chuẩn,Quy chuẩn KT.DOC
# [142/1718] Successfully converted: 786a5340-38eb-4978-aed2-0b6388a446f0.docx
# [143/1718] Successfully converted: 8 HOP DONG- DH 636 (sửa tk bank ngày 1708).doc
# [144/1718] Successfully converted: 8. Hợp đồng đh 203 (Phần 1 - Vector Infotech) draft.docx
# [145/1718] Successfully converted: 8.Mau 08 BB kiêm tra.8.doc
# [146/1718] Successfully converted: 9.Mau 09 CONG BO QD kiem tra.doc
# [147/1718] Successfully converted: 94_2023_ND-CP_589156.doc
# [148/1718] Successfully converted: A20150700-009.doc
# [149/1718] Successfully converted: ACCEPTANCE PROTOCOL_FINAL.doc
# [150/1718] Successfully converted: AFS-09501E Warranty Claim_Return_Repair form - RMA rev6.doc
# [151/1718] Successfully converted: AFS-09501E Warranty Claim_Return_Repair form - RMA rev8.doc
# [152/1718] Successfully converted: Agreement of Joint Venture (Tzone - Vector)  Rev 3 Dec 18.doc
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
